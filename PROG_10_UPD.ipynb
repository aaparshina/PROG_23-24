# %% [markdown]
# # Программирование на Python
#
# # Работа с API: получение токена ВКонтакте
#
# ---
# *Автор: Лика Капустина, НИУ ВШЭ (tg: @lika_kapustina)*
#
# **Содержание:**
# 1. [Введение в API](#par1)
# 3. [Основы работы с API](#par2);
# 3. [Работа с файлами JSON](#par3);
# 5. [API ВКонтакте:  `friends`](#par4);
# 7. [Дополнительные материалы](#parlast)

# %% [markdown]
# ## Введение в API<a name="par1"></a>
#
# **API – Application Programming Interface** – это интерфейс, позволяющий вам взаимодействовать с приложением или веб-сервером.
#
# Чтобы понять, как работает API, разберем на примере – представим, что вы студент, которому нужно забронировать аудиторию для проведения консультации. Делать вы это будете через учебный офис. В этой ситуации:
# * **Вы (студент)** – <font color='green'>пользователь</font>;
# * **Корпоративные системы университета**, через которые бронируется аудитория – это <font color='orange'>сервер</font>;
# * **Учебный офис**, который обрабатывает ваш запрос и бронирует вам аудиторию – это <font color='violet'>API</font>.
#
# Вас не беспокоит в каком формате происходит взаимодействие <font color='violet'>API</font> и <font color='orange'>сервера</font>: через какие внутренние сервисы учебный офис будет проверять доступность аудиторий и бронировать для вас её. Вам (<font color='green'>пользователю</font>) нужно получить только ответ от <font color='violet'>API</font> – то есть, от учебного офиса: письмо о том, что аудитория найдена и забронирована.
#
# **Взаимодействие с API ограничивается прописанными методами, и вы не можете заставить API совершить другое действие**. Например, в случае с учебным офисом, вы можете:
# * Попросить учебный офис прислать вам расписание;
# * Попросить принять вашу справку об уважительной причине пропуска занятий;
# * Забронировать вам аудиторию для консультации или отписать вас от факультатива.
#
# Но у сотрудников учебного офиса есть ряд рабочих обязанностей – это как методы у API, и они не будут делать то что выходит за их пределы. Так, вы не можете попросить сотрудников учебного офиса отменить вам пересдачу, выставить оценку выше реальной или прислать вам мем.
#
# **У API есть особенности, которые мы сейчас с вами увидим:**
# 1. Запросы к API строго унифицированы;
# 2. Перед тем как отправить запрос к API, чаще всего нужно получить токен;
# 3. API отдает вам данные в специальных форматах.

# %% [markdown]
# ## API ВКонтакте: документация и получение доступа <a name="par1"></a>
#
# **API ВКонтакте: документация**
#
# Социальная сеть ВКонтакте имеет очень много сервисов для разработчиков, в том числе, понятный и хорошо задокументированный API. Документация API ВКонтакте доступна по [ссылке](https://dev.vk.com/ru/api/overview).
#
# **API ВКонтакте имеет множество семейств методов**: `Apps`, `Account`, `Adds`, `Photos` и другие. В чем содержательный смысл? Определенное семейство методов отвечает за взаимодействие с определенными объектами – приложениями, аккаунтом, рекламой, фотографиями и т.д.
#
# <p></p>
# <center><b><font size=4>Задача №1</font></b></center>
#
# **Давайте попрактикуемся в работе с API ВКонтакте. Найдите следующие методы и сохраните значения в переменные `answer_1`, `answer_2`, `answer_3`:**
# 1. Метод, с помощью которого можно **сделать пост** на вашей стене;
# 2. Метод, с помощью которого можно **получить детальную информацию** об опросе;
# 3. Метод, с помощью которого можно **получить информацию о подписчиках пользователя**

# %%
answer_1 = # название метода тут
answer_2 = # название метода тут
answer_3 = # название метода тут

# %% [markdown]
# **Что нужно, чтобы пользоваться API ВКонтакте?** Нужно получить специальный токен, который позволит ВКонтакте понимать, что запросы отправляете вы и что вы можете получать только определенные данные в ответ (например, вы можете запросить список сообщений, но должны получить только сообщения, отправленные вами, а не сообщения из переписок которые вели другие пользователи).
#
# **Инструкция по получению токена доступна по [ссылке](https://github.com/lika1kapustina/hse_polit_web-scraping/blob/main/api_vk_get_token_and_test.ipynb).**
#
# **Как выглядит токен ВКонтакте?**
# По структуре он выглядит так, где:
# `vk1.533bacf01e1165expires_in=864000id=1111111`
# * `vk1.533bacf01e1165` – это ваш токен;
# * `expires_in=86400` это число секунд, через которое токен потеряет силу (86400 секунд это 24 часа, то есть этот токен действует 24 часа);
# * `id=1111111` это ваш id пользователя;
#
# **Если вы сгенерировали токен и собираетесь получать данные из ВКонтакте, не пользуйтесь VPN-сервисами и не меняйте IP-адрес**.
# * Если вы включите VPN, то наткнетесь на ошибку `'User authorization failed: access_token was given to another ip address'`.
# * Если отключить VPN, то вы сможете продолжать пользоваться вашим токеном и отправлять запросы к ВКонтакте;
# * Но если вы поменяли IP-адрес, всегда можно перегенерировать токен, сохранить его в переменную, и продолжить работу.
#
# <font color='red'>Важно: не делитесь ни с кем вашим токеном.</font> ВКонтакте ласково напомнит вам об этом в процессе его получения, но запомните – если вы отдадите кому-то свой токен, то можете потерять доступ к аккаунту.
#
# **Когда вы получили токен, сохраните его в переменную в ноутбуке/файле `.py` из которого будете отправлять запросы к API ВКонтакте**.

# %% [markdown]
# ## Основы работы с API<a name="par2"></a>
#
# Чтобы начать, давайте импортируем необходимые библиотеки:

# %%
import requests      # запросы к страницам
import pandas as pd  # работа с таблицами
import json          # работа с файлами json

# %% [markdown]
# 0. **Если мы работаем с новым методом ВКонтакте, то первым делом изучаем справку по нему**: какие параметры можно включить в запрос, какой объект этот метод вернет:
#     * Например, мы решили собрать посты из сообщества с помощью метода `wall.get`. Документация к нему доступна по [ссылке](https://dev.vk.com/ru/method/wall.get);
#     * В документации доступен раздел **Результат**:
# >```После успешного выполнения возвращает объект, содержащий число результатов в поле count и массив объектов записей на стене в поле items. Если был задан параметр extended = 1, возвращает число результатов в поле count, отдельно массив объектов записей на стене в поле items, пользователей в поле profiles и сообществ в поле groups```
#     * Помимо этого, на странице с методом мы **в конце увидим, информацию об объектах какого типа он возвращает**. Там же содержится ссылка на описание этого типа объектов. Для `wall.get` тип объекта – **записи на стене**.
#
# Введем сюда наши данные (хватит только токена):

# %%
token = input('Введите ваш токен тут: ') # вводим токен;
myid = token.split('user_id=')[1]        # получим ваш id пользователя из токена;
version = '5.199'                        # версия api вк, которую вы используете

# %% [markdown]
# 1. **Подбираем параметры запроса к серверу**. <font color='blue'>Эти параметры отличаются для разных методов</font>. На странице с методом `wall.get` указаны параметры, которые нам нужно/можно включить в запрос. А именно:
#     * `owner_id` – Идентификатор пользователя или сообщества, со стены которого необходимо получить записи (по умолчанию — текущий пользователь);
#     * `offset` – Смещение, необходимое для выборки определённого подмножества записей;
#     * `count` – Количество записей, которое необходимо получить. Максимальное значение: `100` (то есть, за один запрос мы можем получить только 100 записей);
#     * `filter` – Определяет, какие типы записей на стене необходимо получить. Возможные значения: `owner` (записи владельца стены), `others` (записи не от владельца стены) и т.д.;
#     * `extended` – Если равен `1` — в ответе будут возвращены дополнительные поля `profiles` и `groups`, содержащие информацию о пользователях и сообществах. По умолчанию: `0`.
#
# Сгенерируем строку, чтобы получить посты сообщества [Уполномоченный по правам студентов и аспирантов НИУ ВШЭ](https://vk.com/ombudsman_hse), используя метод `wall.get`:

# %%
method = 'wall.get'           # метод
group_id = '203966578'        # id групы
offset = 0                    # сдвиг

# Создаем строку с параметрами;
parameters=f'owner_id=-{group_id}&count=5&filter=owner&extended=1&offset={offset}&fields=name,screen_name,members_count'

# %% [markdown]
# 2. **Создаем ссылку для запроса:** <font color='green'>Этот шаблон универсален для всех методов</font>. Как она выглядит? В общем виде так:
#
# >```url = 'https://api.vk.com/method/' + method +'?'+ parameters + '&v=' + version + '&access_token=' + token```
#
# **Где:**
# * `method` - метод (например, `wall.get`);
# * `parameters` – параметры запроса для этого метода (см. предыдущий пункт);
# * `version` – версия API ВКонтакте;
# * `token` – ваш токен.

# %%
# Генерируем ссылку
url = 'https://api.vk.com/method/' + method +'?'+ parameters + '&v=' + version + '&access_token=' + token

# %% [markdown]
# 3. **Отправляем запрос с помощью `requests.get()` и обрабатываем информацию!**

# %%
# Отправляем запрос:
response = requests.get(url) # привет, requests
wall_data = response.json()  # превращаем ответ в объект json, сохраняем в переменную wall_data

# %% [markdown]
# Перед тем, как мы посмотрим на объект `wall_data`, давайте посмотрим на ссылку `url`, которую мы создали. Что же там находится?

# %%
print(f'Откройте ссылку: {url}')

# %% [markdown]
# Верно, там находится ровно та же самая информация, что и в `wall_data`. **Отличие в том,** что мы обработали эти данные с помощью `requests.get()`, преобразовали в **json**, и сохранили в переменную.
#
# ## Работа с файлами JSON <a name='par3'></a>
#
# Что такое **JSON?** – JavaScript Object Notation – текстовый формат обмена файлами, основанный на JavaScript. Большинство API сегодня в качестве ответа возвращают вам объекты этого типа.
#
# Как узнать объект типа JSON? Он будет состоять из **пар "ключ"-"значение"**. Посмотрим на этот пример:
# * Первый ключ – `"0"`, ему соответствует значение из другого словаря, где в качестве ключей используются строки `"Уникальный идентификатор дела"`, `"Номер дела"` и т. д.
# ```
# {
#   "0": {
#     "Уникальный идентификатор дела": "<идентификатор дела>",
#     "Номер дела": "<номер дела>",
#     "Привлекаемое лицо": "<ФИО лица>",
#     "Дата регистрации": "24.12.2019",
#     "Дата рассмотрения дела в первой инстанции": "24.12.2019",
#     "Cудья": "Зубова И.А.",
#     "Статья КоАП РФ": "Ст. 20.2, Ч. 3",
#     "Текущее состояние": "Вступило в силу, 26.06.2020",
#     "files": {
#       "0": {
#         "type": "Постановление о назначении административного наказания",
#         "date": "24.12.2019",
#         "link_to_file": "<ссылка на дело>",
#         "path_to_file": "<название файла>"
#       }
# ```
#
# Теперь давайте исследуем объект `wall_data`:

# %%
wall_data # посмотрим на объект
# Out:
# {'response': {'count': 112,
#   'items': [{'inner_type': 'wall_wallpost',
#     'copy_history': [{'inner_type': 'wall_wallpost',
#       'type': 'post',
#       'attachments': [{'type': 'photo',
#         'photo': {'album_id': -7,
#          'date': 1716293364,
#          'id': 457239710,
#          'owner_id': -110302024,
#          'access_key': '3dfb476a19be9dcfec',
#          'post_id': 1010,
#          'sizes': [{'height': 130,
#            'type': 'm',
#            'width': 130,
#            'url': 'https://sun1-17.userapi.com/impg/L4CuEfzTcLL5hpm56SPaU_P8mXb8u1dzdknY7Q/qYMwo5PLZ_U.jpg?size=130x130&quality=96&sign=9d9581eb63bbbe9a32b01ac1f3bfd883&c_uniq_tag=uu1WIehKhGqGZJaqJGE51u5F7vwKzvbILoza_9-yPp0&type=album'},
#           {'height': 130,
#            'type': 'o',
#            'width': 130,
#            'url': 'https://sun1-17.userapi.com/impg/L4CuEfzTcLL5hpm56SPaU_P8mXb8u1dzdknY7Q/qYMwo5PLZ_U.jpg?size=130x130&quality=96&sign=9d9581eb63bbbe9a32b01ac1f3bfd883&c_uniq_tag=uu1WIehKhGqGZJaqJGE51u5F7vwKzvbILoza_9-yPp0&type=album'},
#           {'height': 200,
#            'type': 'p',
#            'width': 200,
#            'url': 'https://sun1-17.userapi.com/impg/L4CuEfzTcLL5hpm56SPaU_P8mXb8u1dzdknY7Q/qYMwo5PLZ_U.jpg?size=200x200&quality=96&sign=0c38a16438af20304d552edde89a259f&c_uniq_tag=eIic_hJ4lZOn2OqrzL1gs5P3cS2NKncLD3msPfw64J4&type=album'},
#           {'height': 320,
#            'type': 'q',
#            'width': 320,
#            'url': 'https://sun1-17.userapi.com/impg/L4CuEfzTcLL5hpm56SPaU_P8mXb8u1dzdknY7Q/qYMwo5PLZ_U.jpg?size=320x320&quality=96&sign=13a7816d798e5e0bef771ea90c532928&c_uniq_tag=gkiAdrb-5wF02JDXN-vZXWVWrDH6Ro2iO-3WbyXtuRw&type=album'},
#           {'height': 510,
#            'type': 'r',
#            'width': 510,
#            'url': 'https://sun1-17.userapi.com/impg/L4CuEfzTcLL5hpm56SPaU_P8mXb8u1dzdknY7Q/qYMwo5PLZ_U.jpg?size=510x510&quality=96&sign=9f1b451f1293636ac125a6f21dd5b55d&c_uniq_tag=5HqNQFq5P9qc-oEFAJXUn7aXktckzO6NqTgWRlsUEYs&type=album'},
#           {'height': 75,
#            'type': 's',
#            'width': 75,
#            'url': 'https://sun1-17.userapi.com/impg/L4CuEfzTcLL5hpm56SPaU_P8mXb8u1dzdknY7Q/qYMwo5PLZ_U.jpg?size=75x75&quality=96&sign=5623eb79e2a009e5f429cf093c7905b8&c_uniq_tag=Fdko-4q0G_DrvPkvFzNu8NPcTRuiWSFk5aymgtVAxWU&type=album'},
#           {'height': 2160,
#            'type': 'w',
#            'width': 2160,
#            'url': 'https://sun1-17.userapi.com/impg/L4CuEfzTcLL5hpm56SPaU_P8mXb8u1dzdknY7Q/qYMwo5PLZ_U.jpg?size=2160x2160&quality=96&sign=60c6f27d97fc639ce8e18835f0c9a8e6&c_uniq_tag=rg4li_WkpUXiAysCpxhV9ucqXBvlKEs36nIg3S3olkQ&type=album'},
#           {'height': 604,
#            'type': 'x',
#            'width': 604,
#            'url': 'https://sun1-17.userapi.com/impg/L4CuEfzTcLL5hpm56SPaU_P8mXb8u1dzdknY7Q/qYMwo5PLZ_U.jpg?size=604x604&quality=96&sign=91f9cf928e9acb956f76a08bec82764f&c_uniq_tag=RUzWuYkbPlHb8bBlmu5fF_Ow3uNfsxOFHHvA2ngGLfg&type=album'},
#           {'height': 807,
#            'type': 'y',
#            'width': 807,
#            'url': 'https://sun1-17.userapi.com/impg/L4CuEfzTcLL5hpm56SPaU_P8mXb8u1dzdknY7Q/qYMwo5PLZ_U.jpg?size=807x807&quality=96&sign=bd0816b8c16c4ba45e0f76e90aad2426&c_uniq_tag=iMPFKOs2GYXfaM-qa7XI-fKu9881eTRdyiM5n4YtRuw&type=album'},
#           {'height': 1280,
#            'type': 'z',
#            'width': 1280,
#            'url': 'https://sun1-17.userapi.com/impg/L4CuEfzTcLL5hpm56SPaU_P8mXb8u1dzdknY7Q/qYMwo5PLZ_U.jpg?size=1280x1280&quality=96&sign=12f631f295b29381642b2d161056d8b8&c_uniq_tag=Wn7z4l-kuHQr2iJg25ZGpcYK_brXTpwd82SgKbRhBAg&type=album'}],
#          'text': '',
#          'user_id': 100,
#          'web_view_token': 'cf915841e8f3029769',
#          'has_tags': False}}],
#       'date': 1716293364,
#       'from_id': -110302024,
#       'id': 1010,
#       'owner_id': -110302024,
#       'post_source': {'type': 'vk'},
#       'post_type': 'post',
#       'text': 'Дорогие студенты! \n \nПропал студент магистратуры и по совместительству преподаватель Школы дизайна Сабиров Гюльали Гафарович, 2001 года рождения. \n \nПоследний раз его видели около 6:00 в воскресенье (19.05) возле клуба «Симач в Недальнем», его телефон был найден возле станции метро Арбатская. \n \nПриметы Али: Рост 180 см, худощавое телосложение, темно-русые волосы, карие глаза. Он был одет в длинный серый плащ, синий пиджак, белую футболку, синие штаны и черные ботинки с красной подошвой. \n \nЕсли вы обладаете любой информацией, связанной с пропавшим или его нынешним местоположением, просим незамедлительно связаться с Инфоргом от LizaAlert: https://t.me/bananka_la, 89207060294. Мы также будем благодарны за распространение данной записи. \n\nВсю актуальную информацию можно узнать по ссылке: https://lizaalert.org/forum/viewtopic.php?t=77882&p=692835\n \nНа связи, \nВаш Студсовет!'}],
#     'donut': {'is_donut': False},
#     'comments': {'count': 0},
#     'marked_as_ads': 0,
#     'short_text_rate': 0.8,
#     'hash': 'ZCZbESEcSkFLKSLxAidl6WspOJwA',
#     'has_translation': False,
#     'type': 'post',
#     'attachments': [],
#     'date': 1716294173,
#     'from_id': -203966578,
#     'id': 541,
#     'is_favorite': False,
#     'likes': {'can_like': 0, 'count': 5, 'user_likes': 0},
#     'reaction_set_id': 'reactions',
#     'reactions': {'count': 5, 'items': [{'id': 0, 'count': 5}]},
#     'owner_id': -203966578,
#     'post_type': 'post',
#     'reposts': {'count': 0},
#     'text': '',
#     'views': {'count': 133}},
#    {'inner_type': 'wall_wallpost',
#     'donut': {'is_donut': False},
#     'comments': {'count': 5},
#     'marked_as_ads': 0,
#     'short_text_rate': 0.8,
#     'hash': 'Nd43y4j3Cze9PO4unc1xgs9yKrOs',
#     'has_translation': False,
#     'type': 'post',
#     'carousel_offset': 0,
#     'attachments': [{'type': 'photo',
#       'photo': {'album_id': -7,
#        'date': 1716236848,
#        'id': 457239555,
#        'owner_id': -203966578,
#        'access_key': '15a6b18b8bc510a0b0',
#        'sizes': [{'height': 75,
#          'type': 's',
#          'width': 75,
#          'url': 'https://sun9-73.userapi.com/impg/XN3Pn7w1IqSm8FbZ5ziPMHHFE6EKvL5FuDx4Zg/jPyFlhggpAI.jpg?size=75x75&quality=95&sign=39dc34f2a13542d7a89190bea670462c&c_uniq_tag=B_jkhdGamWWJDTbK9oCAeccw0l1G-dm-OaP_CeyXkNE&type=album'},
#         {'height': 130,
#          'type': 'm',
#          'width': 130,
#          'url': 'https://sun9-73.userapi.com/impg/XN3Pn7w1IqSm8FbZ5ziPMHHFE6EKvL5FuDx4Zg/jPyFlhggpAI.jpg?size=130x130&quality=95&sign=c8752325d16d5b1ef42ed60c496bc90a&c_uniq_tag=hlpLq-VzTHHz2UVE4ZvL74uLQv0FdFjGQ5XEUmq84hM&type=album'},
#         {'height': 604,
#          'type': 'x',
#          'width': 604,
#          'url': 'https://sun9-73.userapi.com/impg/XN3Pn7w1IqSm8FbZ5ziPMHHFE6EKvL5FuDx4Zg/jPyFlhggpAI.jpg?size=604x604&quality=95&sign=ba11b7d0285220ee9b2c87791c915f52&c_uniq_tag=OGXWkJnqp5CE0AMRmhcNYFjBo50lNKjoz7Q9nZJurFY&type=album'},
#         {'height': 800,
#          'type': 'y',
#          'width': 800,
#          'url': 'https://sun9-73.userapi.com/impg/XN3Pn7w1IqSm8FbZ5ziPMHHFE6EKvL5FuDx4Zg/jPyFlhggpAI.jpg?size=800x800&quality=95&sign=1fb3b34b49ff75ed93ecdfb9eaeb206e&c_uniq_tag=mHGnlcJSfoyHLVRIa8tPOu1ouxM_FOdYa1n8UsQq_FU&type=album'},
#         {'height': 130,
#          'type': 'o',
#          'width': 130,
#          'url': 'https://sun9
type=album'},
#         {'height': 200,
#          'type': 'p',
#          'width': 200,
#          'url': 'https://sun9-26.userapi.com/impg/01L8D8hkwKCmryMRitZj5fkV26SyW2rS0PEAPQ/By5_dE4VBtY.jpg?size=200x200&quality=95&sign=0493d7f87a4a5d92bda54e12e5189132&c_uniq_tag=b-BAm1jnvYOjINkmHYicmrpWvinZu2gDQvVFr8PZf_0&type=album'},
#         {'height': 320,
#          'type': 'q',
#          'width': 320,
#          'url': 'https://sun9-26.userapi.com/impg/01L8D8hkwKCmryMRitZj5fkV26SyW2rS0PEAPQ/By5_dE4VBtY.jpg?size=320x320&quality=95&sign=5d78e092af53292f459df3cfab704e42&c_uniq_tag=HtB-hb2K9rt4ecOds0suQKcjPGHShImI6ZNZ1ctsfTE&type=album'},
#         {'height': 510,
#          'type': 'r',
#          'width': 510,
#          'url': 'https://sun9-26.userapi.com/impg/01L8D8hkwKCmryMRitZj5fkV26SyW2rS0PEAPQ/By5_dE4VBtY.jpg?size=510x510&quality=95&sign=632e4ff044cb059f5487af7ee96bf633&c_uniq_tag=szTs-wRSLYMzOgpMByFA2xMJ8IQw35EjlFCr-k5Zgec&type=album'}],
#        'text': '',
#        'user_id': 100,
#        'web_view_token': '7213d4e59c683701dc',
#        'has_tags': False}}],
#     'date': 1715277601,
#     'from_id': -203966578,
#     'id': 533,
#     'is_favorite': False,
#     'likes': {'can_like': 0, 'count': 14, 'user_likes': 0},
#     'reaction_set_id': 'reactions',
#     'reactions': {'count': 14, 'items': [{'id': 0, 'count': 14}]},
#     'owner_id': -203966578,
#     'post_type': 'post',
#     'reposts': {'count': 10},
#     'text': 'Друзья!\n \nК нам поступила информация о расклейке персональных уведомлений о необходимости явиться в отделы полиции и о рассылке повесток для явки в Единый Пункт Призыва на улице Яблочкова. Обсудили самое важное со Вторым Отделом и рассказываем вам.\n\nПриводимое относится только к студентам, стоящим на учёте в московских военкоматах!\n\nНекоторые военные комиссариаты ещё выдают отсрочки самостоятельно, но многие уже передают дела на улицу Яблочкова (где и расположен ЕПП) - и в большинстве случаев из-за этого процесса требуется уточнение документов воинского учёта, но уже в ЕПП, а не в вашем районном комиссариате, как это было раньше.\n\nДля перераспределения нагрузки на ЕПП часть полномочий по информированию студентов на себя берут районные ОВД и управы - именно от них вам могли приходить письменные уведомления о необходимости в назначенную дату явиться в конкретный отдел полиции. Пугаться этого не стоит - в ОВД вам просто выдадут повестку в ЕПП после предъявления документов.\n\nВ карточках показываем детально, как всё работает и что важно знать при поездке на Яблочкова!\n\nМы всегда на связи, а ещё советуем ознакомиться с [https://vk.com/@ombudsman_hse-otsrochka-ot-prizyva-faq|предыдущими материалами], посвящёнными призыву. Напомним, что всё вышеописанное актуально только для студентов, приписанных к московским комиссариатам! \n \nПо всем вопросам пишите нам или, если того потребуют обстоятельства, на корпоративный адрес Второго Отдела, указанный на сайте подразделения: https://www.hse.ru/vtotd/\n \nВсегда на связи, \nВаш Аппарат Уполномоченной',
#     'views': {'count': 523}},
#    {'inner_type': 'wall_wallpost',
#     'donut': {'is_donut': False},
#     'comments': {'count': 1},
#     'marked_as_ads': 0,
#     'short_text_rate': 0.8,
#     'hash': 'uNrI_jG79WEqEs7dATEz_hCXLlSY',
#     'has_translation': False,
#     'type': 'post',
#     'attachments': [{'type': 'photo',
#       'photo': {'album_id': -7,
#        'date': 1713164146,
#        'id': 457239539,
#        'owner_id': -203966578,
#        'access_key': 'de753de5a5cd3f5dc7',
#        'post_id': 529,
#        'sizes': [{'height': 75,
#          'type': 's',
#          'width': 75,
#          'url': 'https://s
#     'text': 'Дорогие вышкинцы!\n\nВ связи с чрезвычайной ситуацией в Оренбурге и области, Ситуационный центр НИУ ВШЭ совместно с Уполномоченной по правам студентов и аспирантов готовы оказать помощь студентам и их родственникам, оказавшимся в тяжёлом положении в связи с произошедшими событиями.\n\nКонтакты для связи:\n\n– Почта УПС\nstud.ombudsman@hse.ru\n\n– Рина Егерева (Уполномоченная по правам студентов и аспирантов НИУ ВШЭ):\nТелефон – 89858647110\nВКонтакте – https://vk.com/cheburussia109\nТелеграмм – [id262079240|@doctorina]\n\n– Коля Лобов (Вице-Уполномоченный по правам студентов и аспирантов НИУ ВШЭ):\nТелефон – 89854420405\nВКонтакте – https://vk.com/koluasikk\nТелеграмм – @motherr_duck\n\nКонтакты Ситуационного центра:\n– Прямой телефонный номер Ситцентра\n+7 (495) 628-53-20 (круглосуточно)\n– Электронная почта \nhelp@hse.ru\n\nБерегите себя!\nВаш Аппарат Уполномоченной',
#     'views': {'count': 1470}},
#    {'inner_type': 'wall_wallpost',
#     'donut': {'is_donut': False},
#     'comments': {'count': 1},
#     'marked_as_ads': 0,
#     'short_text_rate': 0.8,
#     'hash': 'Sgr_2XWHEyhYAwxYInqtg_eAQa4o',
#     'has_translation': False,
#     'type': 'post',
#     'attachments': [{'type': 'link',
#       'link': {'url': 'https://m.vk.com/@ombudsman_hse-akademicheskii-otpusk-prosto-o-slozhnom',
#        'caption': 'm.vk.com',
#        'description': 'Статья',
#        'photo': {'album_id': -66,
#         'date': 1712873482,
#         'id': 457239538,
#         'owner_id': -203966578,
#         'sizes': [{'height': 46,
#           'type': 's',
#           'width': 75,
#           'url': 'https://sun9-41.userapi.com/impg/JIHQuNH4sG1rZQeUuab7Cjh4nB-0nA_MgjWQAg/Dq5ZBZVIm6Y.jpg?size=75x46&quality=95&sign=7efb5ad582dcd3c2a7154f3e65abb845&c_uniq_tag=Lf56COW3HnUvpqrzT5HmZf6heT4hnIKV9_TRnYJoUZQ&type=album'},
#          {'height': 79,
#           'type': 'm',
#           'width': 130,
#           'url': 'https://sun9-41.userapi.com/impg/JIHQuNH4sG1rZQeUuab7Cjh4nB-0nA_MgjWQAg/Dq5ZBZVIm6Y.jpg?size=130x79&quality=95&sign=c3c95346c45c76ecba9599479bba46b5&c_uniq_tag=v55c3LXNbh469XxnpJp5geYHY_mcLC_hNBNulgbdqas&type=album'},
#          {'height': 367,
#           'type': 'x',
#           'width': 604,
#           'url': 'https://sun9-41.userapi.com/impg/JIHQuNH4sG1rZQeUuab7Cjh4nB-0nA_MgjWQAg/Dq5ZBZVIm6Y.jpg?size=604x367&quality=95&sign=5f0460d3666b88db6170d759f20538c3&c_uniq_tag=4KAIdMx_J97ApJwWI26dJjJgtt_vIWq1O_klMaDmdls&type=album'},
#          {'height': 491,
#           'type': 'y',
#           'width': 807,
#           'url': 'https://sun9-41.userapi.com/impg/JIHQuNH4sG1rZQeUuab7Cjh4nB-0nA_MgjWQAg/Dq5ZBZVIm6Y.jpg?size=807x491&quality=95&sign=47f227934b890b9d2a5ec282fe9fffff&c_uniq_tag=LUmg5HCabhOcLJNXSQCttEXEMnxmiWAqS1APFAxhpUY&type=album'},
#          {'height': 564,
#           'type': 'z',
#           'width': 927,
#           'url': 'https://sun9-41.userapi.com/impg/JIHQuNH4sG1rZQeUuab7Cjh4nB-0nA_MgjWQAg/Dq5ZBZVIm6Y.jpg?size=927x564&quality=95&sign=b4db58e1ab4a3e54006563dff501c44c&c_uniq_tag=KvyEx4MX9OBEZ5jfG4_0WK5APdgSG2DResJE6A8o9NI&type=album'},
#          {'height': 87,
#           'type': 'o',
#           'width': 130,
#           'url': 'https://sun9-41.userapi.com/impg/JIHQuNH4sG1rZQeUuab7Cjh4nB-0nA_MgjWQAg/Dq5ZBZVIm6Y.jpg?size=130x87&quality=95&crop=42,0,843,564&sign=da65a3d07388d1530d4efc336ddf9d0f&c_uniq_tag=YBuLDum0wpgi6evuNk4_3vd-koqQbH5N8Jzz7RjYOtY&type=album'},
#          {'height': 133,
#           'type': 'p',
#           'width': 200,
#           'url': 'https://sun9-41.userapi.com/impg/JIHQuNH4sG1rZQeUuab7Cjh4nB-0nA_MgjWQAg/Dq5ZBZVIm6Y.jpg?size=200x133&quality=95&crop=39,0,848,564&sign=bb4fe30d6bb2435d0be8425db83bf323&c_uniq_tag=LYhGFoEJ4HoLjVUfUxJgSiatYG6mP-TFooRBiYQdbc8&type=album'},
#          {'height': 213,
#           'type': 'q',
#           'width': 320,
#           'url': 'https://sun9-41.userapi.com/impg/JIHQuNH4sG1rZQeUuab7Cjh4nB-0nA_MgjWQAg/Dq5ZBZVIm6Y.jpg?size=320x213&quality=95&crop=40,0,847,564&sign=c803e8250cea1372d0e3850de36f8e6e&c_uniq_tag=e_V8PvzF-AndzLqpSiYVLpcyVHem2fLYREbVCMJ69OA&type=album'},
#          {'height': 340,
#           'type': 'r',
#           'width': 510,
#           'url': 'https://sun9-41.userapi.com/impg/JIHQuNH4sG1rZQeUuab7Cjh4nB-0nA_MgjWQAg/Dq5ZBZVIm6Y.jpg?size=510x340&quality=95&crop=40,0,846,564&sign=3634774e01985d034f55b8cedcc04a00&c_uniq_tag=T0iCbij6NgD9runp4H4FLm-imkMTy9wURytTShCP8yY&type=album'}],
#         'text': '',
#         'user_id': 100,
#         'web_view_token': 'cc3258f985ab224ae3',
#         'has_tags': False},
#        'title': 'Академический отпуск - просто о сложном'}}],
#     'date': 1713025200,
#     'edited': 1713027025,
#     'from_id': -203966578,
#     'id': 526,
#     'is_favorite': False,
#     'likes': {'can_like': 0, 'count': 13, 'user_likes': 0},
#     'reaction_set_id': 'reactions',
#     'reactions': {'count': 13, 'items': [{'id': 0, 'count': 13}]},
#     'owner_id': -203966578,
#     'post_type': 'post',
#     'reposts': {'count': 3},
#     'text': 'Academic leave - simplified\n❗Check the English version in the comments!\n\nДрузья!\n\nУже вовсю идет 4 учебный модуль, в связи с чем у студентов могут возникать вопросы в связи с выходом из академического отпуска и переносом сессии 3 модуля. Тем временем, некоторые обучающиеся наоборот - изъявляют желание взять временный отдых от учебы.\n\nОсознавая многочисленные вопросы, которые могут возникнуть в данный период, мы собрали всё самое важное об этом процессе - в формате статьи!\n\nГотовый объяснить,\nВаш Аппарат Уполномоченной 💙',
#     'views': {'count': 499}}],
#   'profiles': [{'id': 100,
#     'screen_name': 'id100',
#     'first_name': 'Администрация ВКонтакте',
#     'last_name': '',
#     'can_access_closed': True,
#     'is_closed': False}],
#   'groups': [{'id': 110302024,
#     'members_count': 1953,
#     'name': 'Студенческий совет ФКИ НИУ ВШЭ',
#     'screen_name': 'studsovetfci',
#     'is_closed': 0,
#     'type': 'page',
#     'photo_50': 'https://sun1-19.userapi.com/s/v1/ig2/TJiOL4RTd2f9gWgbdRnoPP3UpuLFXADtxgSxhzmY8k7Dj5Tjp8VYoPRF1_vqhZd_FvHohTCUCBzbHS11mOcrTg8_.jpg?size=50x50&quality=95&crop=0,0,1382,1382&ava=1',
#     'photo_100': 'https://sun1-19.userapi.com/s/v1/ig2/IwgevRFmZXJJ8zUoURBecGHzax37SCG0hNiC_wDXdzu81lZlldjQ_QtwJoHHLTgs3NTNuhVG7VS8NzBMMdWNOwxA.jpg?size=100x100&quality=95&crop=0,0,1382,1382&ava=1',
#     'photo_200': 'https://sun1-19.userapi.com/s/v1/ig2/u-3Cm6dgUYLzCSA4p0zeYzqN1ZOh2Oq4ZSoNealuaozjB4lhVOUdzEURO0HrcI168zDzhUYTrzlP-3dRllLV1Zo1.jpg?size=200x200&quality=95&crop=0,0,1382,1382&ava=1'},
#    {'id': 203966578,
#     'members_count': 1533,
#     'name': 'Уполномоченная по правам студентов НИУ ВШЭ',
#     'screen_name': 'ombudsman_hse',
#     'is_closed': 0,
#     'type': 'page',
#     'photo_50': 'https://sun1-57.userapi.com/s/v1/ig2/z62AU5hRrRQI1kzlpqzsAJtYgGhLpAB0itKNjepO2gbSCPVZZbQjFtQeYvBiIxUh0L3kccrmZAuVQdoNxeqVyBhQ.jpg?size=50x50&quality=96&crop=0,227,1819,1819&ava=1',
#     'photo_100': 'https://sun1-57.userapi.com/s/v1/ig2/P7494n-87s2HwRHVN4kotnYyHpfB88P3-Q0tjQ2M8Jc1E0NYXOB2es0vxmCm9kYIUIinOsxNB6CdjasilE8aPoxx.jpg?size=100x100&quality=96&crop=0,227,1819,1819&ava=1',
#     'photo_200': 'https://sun1-57.userapi.com/s/v1/ig2/SK8b0Ewhf9BJ-2xegajAIfSWScN5w-JHMcjdGGvi7-LEFG8qvuA9VSk1O2mkyhElbtY6kDO8ZoHeOxCEncQuaBui.jpg?size=200x200&quality=96&crop=0,227,1819,1819&ava=1'}],
#   'reaction_sets': [{'id': 'reactions',
#     'items': [{'id': 0,
#       'title': 'Нравится',
#       'asset': {'animation_url': 'https://vk.com/reaction/3-reactions-0?c_uniq_tag=83b2081a8e4adfc36ee536f5f1b4ad470174c89678369a4b9dc5547614a3955e',
#        'images': [{'url': 'https://vk.com/reaction/1-reactions-0-32?c_uniq_tag=464ba6bdc06e9f204a9b2c865a046355d835f601d8d82be4dc77e43a028741ff',
#          'width': 32,
#          'height': 32},
#         {'url': 'https://vk.com/reaction/1-reactions-0-48?c_uniq_tag=e6bee176471af6e4f7ca0f57ac099847d57b8101bf07944e47b42b097a6d8455',
#          'width': 48,
#          'height': 48},
#         {'url': 'https://vk.com/reaction/1-reactions-0-72?c_uniq_tag=d6f55fe94c0add8f817b447cbd804768752eb996c06ef222b39eb3fd35834780',
#          'width': 72,
#          'height': 72},
#         {'url': 'https://vk.com/reaction/1-reactions-0-96?c_uniq_tag=0a64c3d34d3a1368b05716ff24f94ff51b2257a2287957423ced36a00b020cb6',
#          'width': 96,
#          'height': 96},
#         {'url': 'https://vk.com/reaction/1-reactions-0-144?c_uniq_tag=47a911186fd9ce6d9aba1f9273e49ef70d1e0149e7470d1dae40941d81a1ece4',
#          'width': 144,
#          'height': 144}],
#        'title': {'color': {'foreground': {'light': 'FF3347', 'dark': 'FF5C5C'},
#          'background': {'light': 'FFEDED', 'dark': '3E2526'}}},
#        'title_color': {'light': 'FF3347', 'dark': 'FF5C5C'}}},
#      {'id': 1,
#       'title': 'Смешно',
#       'asset': {'animation_url': 'https://vk.com/reaction/3-reactions-1?c_uniq_tag=a47193579880c0f53dd597a15d3bd57d4827820687c73d6128df2720647b42b9',
#        'images': [{'url': 'https://vk.com/reaction/1-reactions-1-32?c_uniq_tag=2119d7ea78675f5702dcf43035f5f7fe13d6dd0f444b3a7d1735699d659b49b7',
#          'width': 32,
#          'height': 32},
#         {'url': 'https://vk.com/reaction/1-reactions-1-48?c_uniq_tag=8f5eb3a1d6a6ec81aceff211782af3c9e9a5d1c837f0bfade6965a6844786f8b',
#          'width': 48,
#          'height': 48},
#         {'url': 'https://vk.com/reaction/1-reactions-1-72?c_uniq_tag=c852fcad6e67059878dcf1905e3e416fd89fbc61222ead100935a6fcc1dab4c9',
#          'width': 72,
#          'height': 72},
#         {'url': 'https://vk.com/reaction/1-reactions-1-96?c_uniq_tag=647ccf722698732a8b13033eadd1f02c5c917b0bdc3f9fb16d6cd0ade8706c99',
#          'width': 96,
#          'height': 96},
#         {'url': 'https://vk.com/reaction/1-reactions-1-144?c_uniq_tag=68c571ccb2f08b9e0404e5307b41a48a057454b44375480a7a89f1dc8fb8b521',
#          'width': 144,
#          'height': 144}],
#        'title': {'color': {'foreground': {'light': 'FF8000', 'dark': 'FFC233'},
#          'background': {'light': 'FFF2D6', 'dark': '352E23'}}},
#        'title_color': {'light': 'FF8000', 'dark': 'FFC233'}}},
#      {'id': 2,
#       'title': 'Ого!',
#       'asset': {'animation_url': 'https://vk.com/reaction/3-reactions-2?c_uniq_tag=b946fcbe262642bc920331746b6eccd9f175bb17d8ef37e54d232fa35ca2c750',
#        'images': [{'url': 'https://vk.com/reaction/1-reactions-2-32?c_uniq_tag=e919477a3e650ebae5d810b30dcc7529a52b072f2470327f95220b778abfb449',
#          'width': 32,
#          'height': 32},
#         {'url': 'https://vk.com/reaction/1-reactions-2-48?c_uniq_tag=2a6544dce8827d216db7ea91eafc726cd3a823f5d465ba00216901a6de2801ad',
#          'width': 48,
#          'height': 48},
#         {'url': 'https://vk.com/reaction/1-reactions-2-72?c_uniq_tag=5a0663f3d38dd6fbcf3e4973610d50641420631c9df30b6cf80eee0dd5c5efee',
#          'width': 72,
#          'height': 72},
#         {'url': 'https://vk.com/reaction/1-reactions-2-96?c_uniq_tag=51275507a335aeafd7c43735d92d11a6b3acf2bb5595273a44a4f844c055b2ce',
#          'width': 96,
#          'height': 96},
#         {'url': 'https://vk.com/reaction/1-reactions-2-144?c_uniq_tag=223a080cabb1e69212b9b1cdb455dcfb8bcbbdc40d93ae339717ecd32ea95f4c',
#          'width': 144,
#          'height': 144}],
#        'title': {'color': {'foreground': {'light': 'FF8000', 'dark': 'FFC233'},
#          'background': {'light': 'FFF2D6', 'dark': '352E23'}}},
#        'title_color': {'light': 'FF8000', 'dark': 'FFC233'}}},
#      {'id': 3,
#       'title': 'Восторг',
#       'asset': {'animation_url': 'https://vk.com/reaction/3-reactions-3?c_uniq_tag=c6ed3add99e841dccda5479c8e21779954e61e0fba15f94a2ae16706df492123',
#        'images': [{'url': 'https://vk.com/reaction/1-reactions-3-32?c_uniq_tag=a95fe4eb836477892e54dcd8f464598e49a611249ec93d5eb7d7a1401cb77cff',
#          'width': 32,
#          'height': 32},
#         {'url': 'https://vk.com/reaction/1-reactions-3-48?c_uniq_tag=eda1a2c18d733b356babdeed5f52cdcc64dd59f1f69776a133fc34a5627eecee',
#          'width': 48,
#          'height': 48},
#         {'url': 'https://vk.com/reaction/1-reactions-3-72?c_uniq_tag=be09c5080773a9ba78984406588c7371e48073e80b842eb7c9a817f7b435379b',
#          'width': 72,
#          'height': 72},
#         {'url': 'https://vk.com/reaction/1-reactions-3-96?c_uniq_tag=b08f5ff31b4bd18e465f14262708e4aac56d34f343b8d355171df7d73bb34497',
#          'width': 96,
#          'height': 96},
#         {'url': 'https://vk.com/reaction/1-reactions-3-144?c_uniq_tag=484984c408a4b1f82d51229ce061ccbc5ad2efffbf2b684636ecfaa60f567f89',
#          'width': 144,
#          'height': 144}],
#        'title': {'color': {'foreground': {'light': 'FF8000', 'dark': 'FFC233'},
#          'background': {'light': 'FFF2D6', 'dark': '352E23'}}},
#        'title_color': {'light': 'FF8000', 'dark': 'FFC233'}}},
#      {'id': 5,
#       'title': 'Печаль',
#       'asset': {'animation_url': 'https://vk.com/reaction/3-reactions-5?c_uniq_tag=c61122c8c334154cb10ccf0e0687057bf1f0f40c2817198b2e1150df534c22c4',
#        'images': [{'url': 'https://vk.com/reaction/1-reactions-5-32?c_uniq_tag=a07ac888553814f1cbc8c9342b636bf30ca6d80d14e7e38170ea02dad0bfafbf',
#          'width': 32,
#          'height': 32},
#         {'url': 'https://vk.com/reaction/1-reactions-5-48?c_uniq_tag=31bcb230babad96120a62589c52af22811aaba54d4ed73a36cfd499d9d94102f',
#          'width': 48,
#          'height': 48},
#         {'url': 'https://vk.com/reaction/1-reactions-5-72?c_uniq_tag=a840d0eb581c133d97638ff5bf34f4b33f3fb8557b932cfe3516925b88e2f151',
#          'width': 72,
#          'height': 72},
#         {'url': 'https://vk.com/reaction/1-reactions-5-96?c_uniq_tag=8cff3bac94202cbb5bee1d598f113134e0038804a3837be750f28ff27d3ffb05',
#          'width': 96,
#          'height': 96},
#         {'url': 'https://vk.com/reaction/1-reactions-5-144?c_uniq_tag=8bf31a92656dd0c0d3482505bf1b6fb3d2493a3e4c93e0e62723aef81c7da052',
#          'width': 144,
#          'height': 144}],
#        'title': {'color': {'foreground': {'light': '4986CC', 'dark': '71AAEB'},
#          'background': {'light': 'EDF3FA', 'dark': '27303C'}}},
#        'title_color': {'light': '4986CC', 'dark': '71AAEB'}}},
#      {'id': 4,
#       'title': '&$#%!',
#       'asset': {'animation_url': 'https://vk.com/reaction/3-reactions-4?c_uniq_tag=063e6b2dd888bb5a9716cf6153f03bf9c0c9707713b857eed8fe1e4e09aea2b3',
#        'images': [{'url': 'https://vk.com/reaction/1-reactions-4-32?c_uniq_tag=ac5ab70367285c3fbbee7ba2adde88cbb65db2d35e05b09b4ae5593ee0bcc535',
#          'width': 32,
#          'height': 32},
#         {'url': 'https://vk.com/reaction/1-reactions-4-48?c_uniq_tag=c80e3224c299a73384c057ff065c9458dcd533d57a1458875eb98883c3a96783',
#          'width': 48,
#          'height': 48},
#         {'url': 'https://vk.com/reaction/1-reactions-4-72?c_uniq_tag=a0eddba1ec31f96adbb9afa2c6c14bec055b95f8d9f113bdf759fb5a9c9054f0',
#          'width': 72,
#          'height': 72},
#         {'url': 'https://vk.com/reaction/1-reactions-4-96?c_uniq_tag=5495709e616048fd43683ac693ebd09f3615c797af2493d0334402befded2885',
#          'width': 96,
#          'height': 96},
#         {'url': 'https://vk.com/reaction/1-reactions-4-144?c_uniq_tag=a79fce98e0d7769284290ab78936b3aa6d15a42caa50e6071bdeb5013d950251',
#          'width': 144,
#          'height': 144}],
#        'title': {'color': {'foreground': {'light': 'EF5203', 'dark': 'FA5300'},
#          'background': {'light': 'FDEBE8', 'dark': '3C2421'}}},
#        'title_color': {'light': 'EF5203', 'dark': 'FA5300'}}}]}]}}

# %%
wall_data.keys() # ключи, которые есть у объекта - только response
# Out:
# dict_keys(['response'])

# %% [markdown]
# Как и в случае со словарями, мы можем обращаться к парам ключ-значение внутри объектов JSON с помощью обращения по ключу внутри квадратных скобок:

# %%
wall_data['response'].keys() # что внутри объекта response?
# Out:
# dict_keys(['count', 'items', 'profiles', 'groups', 'reaction_sets'])

# %% [markdown]
# Давайте исследуем эти объекты. Как к ним обратиться? Вызвать квадратные скобки и написать их название внутри, как когда вы хотите получить значение из словаря по названию ключа:

# %%
wall_data['response']['count'] # 112 - это число постов на стене всего.
# даже если мы запросили всего три последних поста, мы все равно получим этот параметр
# Out:
# 112

# %%
wall_data['response']['groups'] # информация о группах, которые являются авторами постов которые мы получили
# Out:
# [{'id': 110302024,
#   'members_count': 1952,
#   'name': 'Студенческий совет ФКИ НИУ ВШЭ',
#   'screen_name': 'studsovetfci',
#   'is_closed': 0,
#   'type': 'page',
#   'photo_50': 'https://sun1-19.userapi.com/s/v1/ig2/TJiOL4RTd2f9gWgbdRnoPP3UpuLFXADtxgSxhzmY8k7Dj5Tjp8VYoPRF1_vqhZd_FvHohTCUCBzbHS11mOcrTg8_.jpg?size=50x50&quality=95&crop=0,0,1382,1382&ava=1',
#   'photo_100': 'https://sun1-19.userapi.com/s/v1/ig2/IwgevRFmZXJJ8zUoURBecGHzax37SCG0hNiC_wDXdzu81lZlldjQ_QtwJoHHLTgs3NTNuhVG7VS8NzBMMdWNOwxA.jpg?size=100x100&quality=95&crop=0,0,1382,1382&ava=1',
#   'photo_200': 'https://sun1-19.userapi.com/s/v1/ig2/u-3Cm6dgUYLzCSA4p0zeYzqN1ZOh2Oq4ZSoNealuaozjB4lhVOUdzEURO0HrcI168zDzhUYTrzlP-3dRllLV1Zo1.jpg?size=200x200&quality=95&crop=0,0,1382,1382&ava=1'},
#  {'id': 203966578,
#   'members_count': 1533,
#   'name': 'Уполномоченная по правам студентов НИУ ВШЭ',
#   'screen_name': 'ombudsman_hse',
#   'is_closed': 0,
#   'type': 'page',
#   'photo_50': 'https://sun1-57.userapi.com/s/v1/ig2/z62AU5hRrRQI1kzlpqzsAJtYgGhLpAB0itKNjepO2gbSCPVZZbQjFtQeYvBiIxUh0L3kccrmZAuVQdoNxeqVyBhQ.jpg?size=50x50&quality=96&crop=0,227,1819,1819&ava=1',
#   'photo_100': 'https://sun1-57.userapi.com/s/v1/ig2/P7494n-87s2HwRHVN4kotnYyHpfB88P3-Q0tjQ2M8Jc1E0NYXOB2es0vxmCm9kYIUIinOsxNB6CdjasilE8aPoxx.jpg?size=100x100&quality=96&crop=0,227,1819,1819&ava=1',
#   'photo_200': 'https://sun1-57.userapi.com/s/v1/ig2/SK8b0Ewhf9BJ-2xegajAIfSWScN5w-JHMcjdGGvi7-LEFG8qvuA9VSk1O2mkyhElbtY6kDO8ZoHeOxCEncQuaBui.jpg?size=200x200&quality=96&crop=0,227,1819,1819&ava=1'}]

# %%
wall_data['response']['reaction_sets'] # объект с информацией о реакциях;
# Out:
# [{'id': 'reactions',
#   'items': [{'id': 0,
#     'title': 'Нравится',
#     'asset': {'animation_url': 'https://vk.com/reaction/3-reactions-0?c_uniq_tag=83b2081a8e4adfc36ee536f5f1b4ad470174c89678369a4b9dc5547614a3955e',
#      'images': [{'url': 'https://vk.com/reaction/1-reactions-0-32?c_uniq_tag=464ba6bdc06e9f204a9b2c865a046355d835f601d8d82be4dc77e43a028741ff',
#        'width': 32,
#        'height': 32},
#       {'url': 'https://vk.com/reaction/1-reactions-0-48?c_uniq_tag=e6bee176471af6e4f7ca0f57ac099847d57b8101bf07944e47b42b097a6d8455',
#        'width': 48,
#        'height': 48},
#       {'url': 'https://vk.com/reaction/1-reactions-0-72?c_uniq_tag=d6f55fe94c0add8f817b447cbd804768752eb996c06ef222b39eb3fd35834780',
#        'width': 72,
#        'height': 72},
#       {'url': 'https://vk.com/reaction/1-reactions-0-96?c_uniq_tag=0a64c3d34d3a1368b05716ff24f94ff51b2257a2287957423ced36a00b020cb6',
#        'width': 96,
#        'height': 96},
#       {'url': 'https://vk.com/reaction/1-reactions-0-144?c_uniq_tag=47a911186fd9ce6d9aba1f9273e49ef70d1e0149e7470d1dae40941d81a1ece4',
#        'width': 144,
#        'height': 144}],
#      'title': {'color': {'foreground': {'light': 'FF3347', 'dark': 'FF5C5C'},
#        'background': {'light': 'FFEDED', 'dark': '3E2526'}}},
#      'title_color': {'light': 'FF3347', 'dark': 'FF5C5C'}}},
#    {'id': 1,
#     'title': 'Смешно',
#     'asset': {'animation_url': 'https://vk.com/reaction/3-reactions-1?c_uniq_tag=a47193579880c0f53dd597a15d3bd57d4827820687c73d6128df2720647b42b9',
#      'images': [{'url': 'https://vk.com/reaction/1-reactions-1-32?c_uniq_tag=2119d7ea78675f5702dcf43035f5f7fe13d6dd0f444b3a7d1735699d659b49b7',
#        'width': 32,
#        'height': 32},
#       {'url': 'https://vk.com/reaction/1-reactions-1-48?c_uniq_tag=8f5eb3a1d6a6ec81aceff211782af3c9e9a5d1c837f0bfade6965a6844786f8b',
#        'width': 48,
#        'height': 48},
#       {'url': 'https://vk.com/reaction/1-reactions-1-72?c_uniq_tag=c852fcad6e67059878dcf1905e3e416fd89fbc61222ead100935a6fcc1dab4c9',
#        'width': 72,
#        'height': 72},
#       {'url': 'https://vk.com/reaction/1-reactions-1-96?c_uniq_tag=647ccf722698732a8b13033eadd1f02c5c917b0bdc3f9fb16d6cd0ade8706c99',
#        'width': 96,
#        'height': 96},
#       {'url': 'https://vk.com/reaction/1-reactions-1-144?c_uniq_tag=68c571ccb2f08b9e0404e5307b41a48a057454b44375480a7a89f1dc8fb8b521',
#        'width': 144,
#        'height': 144}],
#      'title': {'color': {'foreground': {'light': 'FF8000', 'dark': 'FFC233'},
#        'background': {'light': 'FFF2D6', 'dark': '352E23'}}},
#      'title_color': {'light': 'FF8000', 'dark': 'FFC233'}}},
#    {'id': 2,
#     'title': 'Ого!',
#     'asset': {'animation_url': 'https://vk.com/reaction/3-reactions-2?c_uniq_tag=b946fcbe262642bc920331746b6eccd9f175bb17d8ef37e54d232fa35ca2c750',
#      'images': [{'url': 'https://vk.com/reaction/1-reactions-2-32?c_uniq_tag=e919477a3e650ebae5d810b30dcc7529a52b072f2470327f95220b778abfb449',
#        'width': 32,
#        'height': 32},
#       {'url': 'https://vk.com/reaction/1-reactions-2-48?c_uniq_tag=2a6544dce8827d216db7ea91eafc726cd3a823f5d465ba00216901a6de2801ad',
#        'width': 48,
#        'height': 48},
#       {'url': 'https://vk.com/reaction/1-reactions-2-72?c_uniq_tag=5a0663f3d38dd6fbcf3e4973610d50641420631c9df30b6cf80eee0dd5c5efee',
#        'width': 72,
#        'height': 72},
#       {'url': 'https://vk.com/reaction/1-reactions-2-96?c_uniq_tag=51275507a335aeafd7c43735d92d11a6b3acf2bb5595273a44a4f844c055b2ce',
#        'width': 96,
#        'height': 96},
#       {'url': 'https://vk.com/reaction/1-reactions-2-144?c_uniq_tag=223a080cabb1e69212b9b1cdb455dcfb8bcbbdc40d93ae339717ecd32ea95f4c',
#        'width': 144,
#        'height': 144}],
#      'title': {'color': {'foreground': {'light': 'FF8000', 'dark': 'FFC233'},
#        'background': {'light': 'FFF2D6', 'dark': '352E23'}}},
#      'title_color': {'light': 'FF8000', 'dark': 'FFC233'}}},
#    {'id': 3,
#     'title': 'Восторг',
#     'asset': {'animation_url': 'https://vk.com/reaction/3-reactions-3?c_uniq_tag=c6ed3add99e841dccda5479c8e21779954e61e0fba15f94a2ae16706df492123',
#      'images': [{'url': 'https://vk.com/reaction/1-reactions-3-32?c_uniq_tag=a95fe4eb836477892e54dcd8f464598e49a611249ec93d5eb7d7a1401cb77cff',
#        'width': 32,
#        'height': 32},
#       {'url': 'https://vk.com/reaction/1-reactions-3-48?c_uniq_tag=eda1a2c18d733b356babdeed5f52cdcc64dd59f1f69776a133fc34a5627eecee',
#        'width': 48,
#        'height': 48},
#       {'url': 'https://vk.com/reaction/1-reactions-3-72?c_uniq_tag=be09c5080773a9ba78984406588c7371e48073e80b842eb7c9a817f7b435379b',
#        'width': 72,
#        'height': 72},
#       {'url': 'https://vk.com/reaction/1-reactions-3-96?c_uniq_tag=b08f5ff31b4bd18e465f14262708e4aac56d34f343b8d355171df7d73bb34497',
#        'width': 96,
#        'height': 96},
#       {'url': 'https://vk.com/reaction/1-reactions-3-144?c_uniq_tag=484984c408a4b1f82d51229ce061ccbc5ad2efffbf2b684636ecfaa60f567f89',
#        'width': 144,
#        'height': 144}],
#      'title': {'color': {'foreground': {'light': 'FF8000', 'dark': 'FFC233'},
#        'background': {'light': 'FFF2D6', 'dark': '352E23'}}},
#      'title_color': {'light': 'FF8000', 'dark': 'FFC233'}}},
#    {'id': 5,
#     'title': 'Печаль',
#     'asset': {'animation_url': 'https://vk.com/reaction/3-reactions-5?c_uniq_tag=c61122c8c334154cb10ccf0e0687057bf1f0f40c2817198b2e1150df534c22c4',
#      'images': [{'url': 'https://vk.com/reaction/1-reactions-5-32?c_uniq_tag=a07ac888553814f1cbc8c9342b636bf30ca6d80d14e7e38170ea02dad0bfafbf',
#        'width': 32,
#        'height': 32},
#       {'url': 'https://vk.com/reaction/1-reactions-5-48?c_uniq_tag=31bcb230babad96120a62589c52af22811aaba54d4ed73a36cfd499d9d94102f',
#        'width': 48,
#        'height': 48},
#       {'url': 'https://vk.com/reaction/1-reactions-5-72?c_uniq_tag=a840d0eb581c133d97638ff5bf34f4b33f3fb8557b932cfe3516925b88e2f151',
#        'width': 72,
#        'height': 72},
#       {'url': 'https://vk.com/reaction/1-reactions-5-96?c_uniq_tag=8cff3bac94202cbb5bee1d598f113134e0038804a3837be750f28ff27d3ffb05',
#        'width': 96,
#        'height': 96},
#       {'url': 'https://vk.com/reaction/1-reactions-5-144?c_uniq_tag=8bf31a92656dd0c0d3482505bf1b6fb3d2493a3e4c93e0e62723aef81c7da052',
#        'width': 144,
#        'height': 144}],
#      'title': {'color': {'foreground': {'light': '4986CC', 'dark': '71AAEB'},
#        'background': {'light': 'EDF3FA', 'dark': '27303C'}}},
#      'title_color': {'light': '4986CC', 'dark': '71AAEB'}}},
#    {'id': 4,
#     'title': '&$#%!',
#     'asset': {'animation_url': 'https://vk.com/reaction/3-reactions-4?c_uniq_tag=063e6b2dd888bb5a9716cf6153f03bf9c0c9707713b857eed8fe1e4e09aea2b3',
#      'images': [{'url': 'https://vk.com/reaction/1-reactions-4-32?c_uniq_tag=ac5ab70367285c3fbbee7ba2adde88cbb65db2d35e05b09b4ae5593ee0bcc535',
#        'width': 32,
#        'height': 32},
#       {'url': 'https://vk.com/reaction/1-reactions-4-48?c_uniq_tag=c80e3224c299a73384c057ff065c9458dcd533d57a1458875eb98883c3a96783',
#        'width': 48,
#        'height': 48},
#       {'url': 'https://vk.com/reaction/1-reactions-4-72?c_uniq_tag=a0eddba1ec31f96adbb9afa2c6c14bec055b95f8d9f113bdf759fb5a9c9054f0',
#        'width': 72,
#        'height': 72},
#       {'url': 'https://vk.com/reaction/1-reactions-4-96?c_uniq_tag=5495709e616048fd43683ac693ebd09f3615c797af2493d0334402befded2885',
#        'width': 96,
#        'height': 96},
#       {'url': 'https://vk.com/reaction/1-reactions-4-144?c_uniq_tag=a79fce98e0d7769284290ab78936b3aa6d15a42caa50e6071bdeb5013d950251',
#        'width': 144,
#        'height': 144}],
#      'title': {'color': {'foreground': {'light': 'EF5203', 'dark': 'FA5300'},
#        'background': {'light': 'FDEBE8', 'dark': '3C2421'}}},
#      'title_color': {'light': 'EF5203', 'dark': 'FA5300'}}}]}]

# %% [markdown]
# А теперь посмотрим на самый интересный объект - `items`. Что здесь находится? Здесь находится информация о всех постах.

# %%
wall_data['response']['items']
# Out:
# [{'inner_type': 'wall_wallpost',
#   'copy_history': [{'inner_type': 'wall_wallpost',
#     'type': 'post',
#     'attachments': [{'type': 'photo',
#       'photo': {'album_id': -7,
#        'date': 1716293364,
#        'id': 457239710,
#        'owner_id': -110302024,
#        'access_key': '3dfb476a19be9dcfec',
#        'post_id': 1010,
#        'sizes': [{'height': 130,
#          'type': 'm',
#          'width': 130,
#          'url': 'https://sun1-17.userapi.com/impg/L4CuEfzTcLL5hpm56SPaU_P8mXb8u1dzdknY7Q/qYMwo5PLZ_U.jpg?size=130x130&quality=96&sign=9d9581eb63bbbe9a32b01ac1f3bfd883&c_uniq_tag=uu1WIehKhGqGZJaqJGE51u5F7vwKzvbILoza_9-yPp0&type=album'},
#         {'height': 130,
#          'type': 'o',
#          'width': 130,
#          'url': 'https://sun1-17.userapi.com/impg/L4CuEfzTcLL5hpm56SPaU_P8mXb8u1dzdknY7Q/qYMwo5PLZ_U.jpg?size=130x130&quality=96&sign=9d9581eb63bbbe9a32b01ac1f3bfd883&c_uniq_tag=uu1WIehKhGqGZJaqJGE51u5F7vwKzvbILoza_9-yPp0&type=album'},
#         {'height': 200,
#          'type': 'p',
#          'width': 200,
#          'url': 'https://sun1-17.userapi.com/impg/L4CuEfzTcLL5hpm56SPaU_P8mXb8u1dzdknY7Q/qYMwo5PLZ_U.jpg?size=200x200&quality=96&sign=0c38a16438af20304d552edde89a259f&c_uniq_tag=eIic_hJ4lZOn2OqrzL1gs5P3cS2NKncLD3msPfw64J4&type=album'},
#         {'height': 320,
#          'type': 'q',
#          'width': 320,
#          'url': 'https://sun1-17.userapi.com/impg/L4CuEfzTcLL5hpm56SPaU_P8mXb8u1dzdknY7Q/qYMwo5PLZ_U.jpg?size=320x320&quality=96&sign=13a7816d798e5e0bef771ea90c532928&c_uniq_tag=gkiAdrb-5wF02JDXN-vZXWVWrDH6Ro2iO-3WbyXtuRw&type=album'},
#         {'height': 510,
#          'type': 'r',
#          'width': 510,
#          'url': 'https://sun1-17.userapi.com/impg/L4CuEfzTcLL5hpm56SPaU_P8mXb8u1dzdknY7Q/qYMwo5PLZ_U.jpg?size=510x510&quality=96&sign=9f1b451f1293636ac125a6f21dd5b55d&c_uniq_tag=5HqNQFq5P9qc-oEFAJXUn7aXktckzO6NqTgWRlsUEYs&type=album'},
#         {'height': 75,
#          'type': 's',
#          'width': 75,
#          'url': 'https://sun1-17.userapi.com/impg/L4CuEfzTcLL5hpm56SPaU_P8mXb8u1dzdknY7Q/qYMwo5PLZ_U.jpg?size=75x75&quality=96&sign=5623eb79e2a009e5f429cf093c7905b8&c_uniq_tag=Fdko-4q0G_DrvPkvFzNu8NPcTRuiWSFk5aymgtVAxWU&type=album'},
#         {'height': 2160,
#          'type': 'w',
#          'width': 2160,
#          'url': 'https://sun1-17.userapi.com/impg/L4CuEfzTcLL5hpm56SPaU_P8mXb8u1dzdknY7Q/qYMwo5PLZ_U.jpg?size=2160x2160&quality=96&sign=60c6f27d97fc639ce8e18835f0c9a8e6&c_uniq_tag=rg4li_WkpUXiAysCpxhV9ucqXBvlKEs36nIg3S3olkQ&type=album'},
#         {'height': 604,
#          'type': 'x',
#          'width': 604,
#          'url': 'https://sun1-17.userapi.com/impg/L4CuEfzTcLL5hpm56SPaU_P8mXb8u1dzdknY7Q/qYMwo5PLZ_U.jpg?size=604x604&quality=96&sign=91f9cf928e9acb956f76a08bec82764f&c_uniq_tag=RUzWuYkbPlHb8bBlmu5fF_Ow3uNfsxOFHHvA2ngGLfg&type=album'},
#         {'height': 807,
#          'type': 'y',
#          'width': 807,
#          'url': 'https://sun1-17.userapi.com/impg/L4CuEfzTcLL5hpm56SPaU_P8mXb8u1dzdknY7Q/qYMwo5PLZ_U.jpg?size=807x807&quality=96&sign=bd0816b8c16c4ba45e0f76e90aad2426&c_uniq_tag=iMPFKOs2GYXfaM-qa7XI-fKu9881eTRdyiM5n4YtRuw&type=album'},
#         {'height': 1280,
#          'type': 'z',
#          'width': 1280,
#          'url': 'https://sun1-17.userapi.com/impg/L4CuEfzTcLL5hpm56SPaU_P8mXb8u1dzdknY7Q/qYMwo5PLZ_U.jpg?size=1280x1280&quality=96&sign=12f631f295b29381642b2d161056d8b8&c_uniq_tag=Wn7z4l-kuHQr2iJg25ZGpcYK_brXTpwd82SgKbRhBAg&type=album'}],
#        'text': '',
#        'user_id': 100,
#        'web_view_token': 'cf915841e8f3029769',
#        'has_tags': False}}],
#     'date': 1716293364,
#     'from_id': -110302024,
#     'id': 1010,
#     'owner_id': -110302024,
#     'post_source': {'type': 'vk'},
#     'post_type': 'post',
#     'text': 'Дорогие студенты! \n \nПропал студент магистратуры и по совместительству преподаватель Школы дизайна Сабиров Гюльали Гафарович, 2001 года рождения. \n \nПоследний раз его видели около 6:00 в воскресенье (19.05) возле клуба «Симач в Недальнем», его телефон был найден возле станции метро Арбатская. \n \nПриметы Али: Рост 180 см, худощавое телосложение, темно-русые волосы, карие глаза. Он был одет в длинный серый плащ, синий пиджак, белую футболку, синие штаны и черные ботинки с красной подошвой. \n \nЕсли вы обладаете любой информацией, связанной с пропавшим или его нынешним местоположением, просим незамедлительно связаться с Инфоргом от LizaAlert: https://t.me/bananka_la, 89207060294. Мы также будем благодарны за распространение данной записи. \n\nВсю актуальную информацию можно узнать по ссылке: https://lizaalert.org/forum/viewtopic.php?t=77882&p=692835\n \nНа связи, \nВаш Студсовет!'}],
#   'donut': {'is_donut': False},
#   'comments': {'count': 0},
#   'marked_as_ads': 0,
#   'short_text_rate': 0.8,
#   'hash': 'ZCZbESEcSkFLKSLxAidl6WspOJwA',
#   'has_translation': False,
#   'type': 'post',
#   'attachments': [],
#   'date': 1716294173,
#   'from_id': -203966578,
#   'id': 541,
#   'is_favorite': False,
#   'likes': {'can_like': 0, 'count': 5, 'user_likes': 0},
#   'reaction_set_id': 'reactions',
#   'reactions': {'count': 5, 'items': [{'id': 0, 'count': 5}]},
#   'owner_id': -203966578,
#   'post_type': 'post',
#   'reposts': {'count': 0},
#   'text': '',
#   'views': {'count': 133}},
#  {'inner_type': 'wall_wallpost',
#   'donut': {'is_donut': False},
#   'comments': {'count': 5},
#   'marked_as_ads': 0,
#   'short_text_rate': 0.8,
#   'hash': 'Nd43y4j3Cze9PO4unc1xgs9yKrOs',
#   'has_translation': False,
#   'type': 'post',
#   'carousel_offset': 0,
#   'attachments': [{'type': 'photo',
#     'photo': {'album_id': -7,
#      'date': 1716236848,
#      'id': 457239555,
#      'owner_id': -203966578,
#      'access_key': '15a6b18b8bc510a0b0',
#      'sizes': [{'height': 75,
#        'type': 's',
#        'width': 75,
#        'url': 'https://sun9
type=album'},
#       {'height': 320,
#        'type': 'q',
#        'width': 320,
#        'url': 'https://sun1-16.userapi.com/impg/1c_GFt00PasTI685JuTuJWlBN3QUiROsoLLf5A/BNaJE9gieM8.jpg?size=320x320&quality=95&sign=e2512ce9b5550ddcb93476fe5f412922&c_uniq_tag=9LLP1tkx_-qVoj2h5_HmUyuhO3qTqJBjAe2JbvxuM2c&type=album'},
#       {'height': 510,
#        'type': 'r',
#        'width': 510,
#        'url': 'https://sun1-16.userapi.com/impg/1c_GFt00PasTI685JuTuJWlBN3QUiROsoLLf5A/BNaJE9gieM8.jpg?size=510x510&quality=95&sign=e378d200d210fd4e43bc9c0a13b7efa3&c_uniq_tag=pMmdxT__UUhp4flSTgHjQliEEYZdi2bIG-PRm6v13Ac&type=album'}],
#      'text': '',
#      'user_id': 100,
#      'web_view_token': 'af10043cc4b2c04336',
#      'has_tags': False}},
#    {'type': 'link',
#     'link': {'url': 'https://drive.google.com/file/d/1fwY8pXR5Rlk1kEsrZGeKJqAqK78NTimS/view',
#      'description': '',
#      'is_favorite': False,
#      'title': 'Инструкция для прохождения тестирования Иннополиса.pdf',
#      'target': 'internal'}}],
#   'date': 1716234582,
#   'edited': 1716302619,
#   'from_id': -203966578,
#   'id': 535,
#   'is_favorite': False,
#   'likes': {'can_like': 0, 'count': 10, 'user_likes': 0},
#   'reaction_set_id': 'reactions',
#   'reactions': {'count': 10,
#    'items': [{'id': 0, 'count': 9}, {'id': 4, 'count': 1}]},
#   'owner_id': -203966578,
#   'post_type': 'post',
#   'reposts': {'count': 11},
#   'text': '❗Check the English version in the comments!\n\nДорогие студенты и студентки 2 курса!\n \nВ этом году вы уже столкнулись с этапами Иннополиса, и сейчас мы хотим поподробнее рассказать, что вас ждет дальше и как подготовиться к следующим этапам.\n \nПрежде всего напоминаем, что всю основную информацию об Иннополисе можно найти здесь: https://vk.cc/cwZebJ\nА инструкции по работе с платформой тестирования — здесь: https://vk.cc/cwZe9b\n \nЕсли возникают проблемы в ходе тестирования, пишите по почте assesment.support@innopolis.university \nА о самом важном расскажем в карточках! \n\nС заботой,\nВаш Аппарат Уполномоченной!',
#   'views': {'count': 379}},
#  {'inner_type': 'wall_wallpost',
#   'donut': {'is_donut': False},
#   'comments': {'count': 1},
#   'marked_as_ads': 0,
#   'short_text_rate': 0.8,
#   'hash': 't5V4hrh-4kZap-ylebbfNhR3nakr',
#   'has_translation': False,
#   'type': 'post',
#   'carousel_offset': 0,
#   'attachments': [{'type': 'photo',
#     'photo': {'album_id': -7,
#      'date': 1715273764,
#      'id': 457239542,
#      'owner_id': -203966578,
#      'access_key': '9377ff9178684ebaee',
#      'sizes': [{'height': 75,
#        'type': 's',
#        'width': 75,
#        'url': 'https://sun9-60.userapi.com/impg/JwlJzuvvmf_kYjXqQ2wphYqxLcpebBh3so0NvQ/JvlzMH5eYuc.jpg?size=75x75&quality=95&sign=6e0fe5ac6a4806689dc446bff74db538&c_uniq_tag=TcX1rvCcErP-DIPzvPlpCFGqsxQ1EXinLaThMQuizes&type=album'},
#       {'height': 130,
#        'type': 'm',
#        'width': 130,
#        'url': 'https://sun9-60.userapi.com/impg/JwlJzuvvmf_kYjXqQ2wphYqxLcpebBh3so0NvQ/JvlzMH5eYuc.jpg?size=130x130&quality=95&sign=f5b09da38b3e1b1d1cf886fe0dc01ccb&c_uniq_tag=2nT1SHWbzMVtwtMxwB5n1jLwDxb_cBbQ4QDNDGcWIUg&type=album'},
#       {'height': 602,
#        'type': 'x',
#        'width': 604,
#        'url': 'https://sun9-60.userapi.com/impg/JwlJzuvvmf_kYjXqQ2wphYqxLcpebBh3so0NvQ/JvlzMH5eYuc.jpg?size=604x602&quality=95&sign=c7e0535938f514bb59184ba8219b3dce&c_uniq_tag=ey7Cq6B5PZuQuuP9Mxxz05ngoJ3P4fhFTk3DvvDkxCo&type=album'},
#       {'height': 800,
#        'type': 'y',
#        'width':
уведомления о необходимости в назначенную дату явиться в конкретный отдел полиции. Пугаться этого не стоит - в ОВД вам просто выдадут повестку в ЕПП после предъявления документов.\n\nВ карточках показываем детально, как всё работает и что важно знать при поездке на Яблочкова!\n\nМы всегда на связи, а ещё советуем ознакомиться с [https://vk.com/@ombudsman_hse-otsrochka-ot-prizyva-faq|предыдущими материалами], посвящёнными призыву. Напомним, что всё вышеописанное актуально только для студентов, приписанных к московским комиссариатам! \n \nПо всем вопросам пишите нам или, если того потребуют обстоятельства, на корпоративный адрес Второго Отдела, указанный на сайте подразделения: https://www.hse.ru/vtotd/\n \nВсегда на связи, \nВаш Аппарат Уполномоченной',
#   'views': {'count': 523}},
#  {'inner_type': 'wall_wallpost',
#   'donut': {'is_donut': False},
#   'comments': {'count': 1},
#   'marked_as_ads': 0,
#   'short_text_rate': 0.8,
#   'hash': 'uNrI_jG79WEqEs7dATEz_hCXLlSY',
#   'has_translation': False,
#   'type': 'post',
#   'attachments': [{'type': 'photo',
#     'photo': {'album_id': -7,
#      'date': 1713164146,
#      'id': 457239539,
#      'owner_id': -203966578,
#      'access_key': 'de753de5a5cd3f5dc7',
#      'post_id': 529,
#      'sizes': [{'height': 75,
#        'type': 's',
#        'width': 75,
#        'url': 'https://sun9-78.userapi.com/impg/j1TXSWXr4hFFx6RNA0tE10ufnbYp36aGMooYdg/MET9_T1_al0.jpg?size=75x75&quality=95&sign=2d4f574dfc64fcb24bdf330ff02929bf&c_uniq_tag=c7ZVV9Vf9vAj3Bxuys4B715FW3V204DdTX8nPxw_2H0&type=album'},
#       {'height': 130,
#        'type': 'm',
#        'width': 130,
#        'url': 'https://sun9-78.userapi.com/impg/j1TXSWXr4hFFx6RNA0tE10ufnbYp36aGMooYdg/MET9_T1_al0.jpg?size=130x130&quality=95&sign=90904a80d56a3e811244e7e37a8cc16c&c_uniq_tag=14syrbEyzU5CKFRLlJlioUDyp3VadMej1ZqWQWC1mHk&type=album'},
#       {'height': 602,
#        'type': 'x',
#        'width': 604,
#        'url': 'https://sun9-78.userapi.com/impg/j1TXSWXr4hFFx6RNA0tE10ufnbYp36aGMooYdg/MET9_T1_al0.jpg?size=604x602&quality=95&sign=73a535f22ab0b9cbd3f33789bae3b94c&c_uniq_tag=so_wenl1cKNz_PL0WEIv8CEbHjiP_AhQCMxBwBYiuBY&type=album'},
#       {'height': 800,
#        'type': 'y',
#        'width': 803,
#        'url': 'https://sun9-78.userapi.com/impg/j1TXSWXr4hFFx6RNA0tE10ufnbYp36aGMooYdg/MET9_T1_al0.jpg?size=803x800&quality=95&sign=148699e7c9c104baa15c35057b31a196&c_uniq_tag=2J1BzDQIr5H2SvkCYea2Gc2_K1YlFA1bdFh0MNMEAHY&type=album'},
#       {'height': 130,
#        'type': 'o',
#        'width': 130,
#        'url': 'https://sun9-78.userapi.com/impg/j1TXSWXr4hFFx6RNA0tE10ufnbYp36aGMooYdg/MET9_T1_al0.jpg?size=130x130&quality=95&sign=90904a80d56a3e811244e7e37a8cc16c&c_uniq_tag=14syrbEyzU5CKFRLlJlioUDyp3VadMej1ZqWQWC1mHk&type=album'},
#       {'height': 199,
#        'type': 'p',
#        'width': 200,
#        'url': 'https://sun9-78.userapi.com/impg/j1TXSWXr4hFFx6RNA0tE10ufnbYp36aGMooYdg/MET9_T1_al0.jpg?size=200x199&quality=95&sign=9226cedee292b288dcf213bbbe76924b&c_uniq_tag=YNW_Ley3YwDUYdLjw5JlxGkYlWRAorZ-KVozSRTkGtI&type=album'},
#       {'height': 319,
#        'type': 'q',
#        'width': 320,
#        'url': 'https://sun9-78.userapi.com/impg/j1TXSWXr4hFFx6RNA0tE10ufnbYp36aGMooYdg/MET9_T1_al0.jpg?size=320x319&quality=95&sign=3510e79b3d2d83a24c6f52cf2808bebc&c_uniq_tag=difntzh2mUSdPtjj3mXQ82hAO-TlI4kQVs12PB7icSo&type=album'},
#       {'height': 508,
#        'type': 'r',
#        'width': 510,
#        'url': 'https://sun9-78.userapi.com/impg/j1TXSWXr4hFFx6RNA0tE10ufnbYp36aGMooYdg/MET9_T1_al0.jpg?size=510x508&quality=95&sign=adc595c55563feee09522681d4976cd9&c_uniq_tag=dNWEhCuTDDWJfe92Sqj1NXvmH-83mKISXdjYx8uLc64&type=album'}],
#      'text': '',
#      'user_id': 100,
#      'web_view_token': 'e233f3c72432c16c06',
#      'has_tags': False}}],
#   'date': 1713164404,
#   'from_id': -203966578,
#   'id': 529,
#   'is_favorite': False,
#   'likes': {'can_like': 0, 'count': 15, 'user_likes': 0},
#   'reaction_set_id': 'reactions',
#   'reactions': {'count': 15, 'items': [{'id': 0, 'count': 15}]},
#   'owner_id': -203966578,
#   'post_type': 'post',
#   'reposts': {'count': 1},
#   'text': 'Дорогие вышкинцы!\n\nВ связи с чрезвычайной ситуацией в Оренбурге и области, Ситуационный центр НИУ ВШЭ совместно с Уполномоченной по правам студентов и аспирантов готовы оказать помощь студентам и их родственникам, оказавшимся в тяжёлом положении в связи с произошедшими событиями.\n\nКонтакты для связи:\n\n– Почта УПС\nstud.ombudsman@hse.ru\n\n– Рина Егерева (Уполномоченная по правам студентов и аспирантов НИУ ВШЭ):\nТелефон – 89858647110\nВКонтакте – https://vk.com/cheburussia109\nТелеграмм – [id262079240|@doctorina]\n\n– Коля Лобов (Вице-Уполномоченный по правам студентов и аспирантов НИУ ВШЭ):\nТелефон – 89854420405\nВКонтакте – https://vk.com/koluasikk\nТелеграмм – @motherr_duck\n\nКонтакты Ситуационного центра:\n– Прямой телефонный номер Ситцентра\n+7 (495) 628-53-20 (круглосуточно)\n– Электронная почта \nhelp@hse.ru\n\nБерегите себя!\nВаш Аппарат Уполномоченной',
#   'views': {'count': 1470}},
#  {'inner_type': 'wall_wallpost',
#   'donut': {'is_donut': False},
#   'comments': {'count': 1},
#   'marked_as_ads': 0,
#   'short_text_rate': 0.8,
#   'hash': 'Sgr_2XWHEyhYAwxYInqtg_eAQa4o',
#   'has_translation': False,
#   'type': 'post',
#   'attachments': [{'type': 'link',
#     'link': {'url': 'https://m.vk.com/@ombudsman_hse-akademicheskii-otpusk-prosto-o-slozhnom',
#      'caption': 'm.vk.com',
#      'description': 'Статья',
#      'photo': {'album_id': -66,
#       'date': 1712873482,
#       'id': 457239538,
#       'owner_id': -203966578,
#       'sizes': [{'height': 46,
#         'type': 's',
#         'width': 75,
#         'url': 'https://sun9-41.userapi.com/impg/JIHQuNH4sG1rZQeUuab7Cjh4nB-0nA_MgjWQAg/Dq5ZBZVIm6Y.jpg?size=75x46&quality=95&sign=7efb5ad582dcd3c2a7154f3e65abb845&c_uniq_tag=Lf56COW3HnUvpqrzT5HmZf6heT4hnIKV9_TRnYJoUZQ&type=album'},
#        {'height': 79,
#         'type': 'm',
#         'width': 130,
#         'url': 'https://sun9-41.userapi.com/impg/JIHQuNH4sG1rZQeUuab7Cjh4nB-0nA_MgjWQAg/Dq5ZBZVIm6Y.jpg?size=130x79&quality=95&sign=c3c95346c45c76ecba9599479bba46b5&c_uniq_tag=v55c3LXNbh469XxnpJp5geYHY_mcLC_hNBNulgbdqas&type=album'},
#        {'height': 367,
#         'type': 'x',
#         'width': 604,
#         'url': 'https://sun9-41.userapi.com/impg/JIHQuNH4sG1rZQeUuab7Cjh4nB-0nA_MgjWQAg/Dq5ZBZVIm6Y.jpg?size=604x367&quality=95&sign=5f0460d3666b88db6170d759f20538c3&c_uniq_tag=4KAIdMx_J97ApJwWI26dJjJgtt_vIWq1O_klMaDmdls&type=album'},
#        {'height': 491,
#         'type': 'y',
#         'width': 807,
#         'url': 'https://sun9-41.userapi.com/impg/JIHQuNH4sG1rZQeUuab7Cjh4nB-0nA_MgjWQAg/Dq5ZBZVIm6Y.jpg?size=807x491&quality=95&sign=47f227934b890b9d2a5ec282fe9fffff&c_uniq_tag=LUmg5HCabhOcLJNXSQCttEXEMnxmiWAqS1APFAxhpUY&type=album'},
#        {'height': 564,
#         'type': 'z',
#         'width': 927,
#         'url': 'https://sun9-41.userapi.com/impg/JIHQuNH4sG1rZQeUuab7Cjh4nB-0nA_MgjWQAg/Dq5ZBZVIm6Y.jpg?size=927x564&quality=95&sign=b4db58e1ab4a3e54006563dff501c44c&c_uniq_tag=KvyEx4MX9OBEZ5jfG4_0WK5APdgSG2DResJE6A8o9NI&type=album'},
#        {'height': 87,
#         'type': 'o',
#         'width': 130,
#         'url': 'https://sun9-41.userapi.com/impg/JIHQuNH4sG1rZQeUuab7Cjh4nB-0nA_MgjWQAg/Dq5ZBZVIm6Y.jpg?size=130x87&quality=95&crop=42,0,843,564&sign=da65a3d07388d1530d4efc336ddf9d0f&c_uniq_tag=YBuLDum0wpgi6evuNk4_3vd-koqQbH5N8Jzz7RjYOtY&type=album'},
#        {'height': 133,
#         'type': 'p',
#         'width': 200,
#         'url': 'https://sun9-41.userapi.com/impg/JIHQuNH4sG1rZQeUuab7Cjh4nB-0nA_MgjWQAg/Dq5ZBZVIm6Y.jpg?size=200x133&quality=95&crop=39,0,848,564&sign=bb4fe30d6bb2435d0be8425db83bf323&c_uniq_tag=LYhGFoEJ4HoLjVUfUxJgSiatYG6mP-TFooRBiYQdbc8&type=album'},
#        {'height': 213,
#         'type': 'q',
#         'width': 320,
#         'url': 'https://sun9-41.userapi.com/impg/JIHQuNH4sG1rZQeUuab7Cjh4nB-0nA_MgjWQAg/Dq5ZBZVIm6Y.jpg?size=320x213&quality=95&crop=40,0,847,564&sign=c803e8250cea1372d0e3850de36f8e6e&c_uniq_tag=e_V8PvzF-AndzLqpSiYVLpcyVHem2fLYREbVCMJ69OA&type=album'},
#        {'height': 340,
#         'type': 'r',
#         'width': 510,
#         'url': 'https://sun9-41.userapi.com/impg/JIHQuNH4sG1rZQeUuab7Cjh4nB-0nA_MgjWQAg/Dq5ZBZVIm6Y.jpg?size=510x340&quality=95&crop=40,0,846,564&sign=3634774e01985d034f55b8cedcc04a00&c_uniq_tag=T0iCbij6NgD9runp4H4FLm-imkMTy9wURytTShCP8yY&type=album'}],
#       'text': '',
#       'user_id': 100,
#       'web_view_token': 'cc3258f985ab224ae3',
#       'has_tags': False},
#      'title': 'Академический отпуск - просто о сложном'}}],
#   'date': 1713025200,
#   'edited': 1713027025,
#   'from_id': -203966578,
#   'id': 526,
#   'is_favorite': False,
#   'likes': {'can_like': 0, 'count': 13, 'user_likes': 0},
#   'reaction_set_id': 'reactions',
#   'reactions': {'count': 13, 'items': [{'id': 0, 'count': 13}]},
#   'owner_id': -203966578,
#   'post_type': 'post',
#   'reposts': {'count': 3},
#   'text': 'Academic leave - simplified\n❗Check the English version in the comments!\n\nДрузья!\n\nУже вовсю идет 4 учебный модуль, в связи с чем у студентов могут возникать вопросы в связи с выходом из академического отпуска и переносом сессии 3 модуля. Тем временем, некоторые обучающиеся наоборот - изъявляют желание взять временный отдых от учебы.\n\nОсознавая многочисленные вопросы, которые могут возникнуть в данный период, мы собрали всё самое важное об этом процессе - в формате статьи!\n\nГотовый объяснить,\nВаш Аппарат Уполномоченной 💙',
#   'views': {'count': 499}}]

# %% [markdown]
# JSON файлы поддерживают индексацию: мы можем обратиться к первому или последнему элементу в items:

# %%
wall_data['response']['items'][0] # обращаемся к первому посту
# Out:
# {'inner_type': 'wall_wallpost',
#  'copy_history': [{'inner_type': 'wall_wallpost',
#    'type': 'post',
#    'attachments': [{'type': 'photo',
#      'photo': {'album_id': -7,
#       'date': 1716293364,
#       'id': 457239710,
#       'owner_id': -110302024,
#       'access_key': '3dfb476a19be9dcfec',
#       'post_id': 1010,
#       'sizes': [{'height': 130,
#         'type': 'm',
#         'width': 130,
#         'url': 'https://sun1-17.userapi.com/impg/L4CuEfzTcLL5hpm56SPaU_P8mXb8u1dzdknY7Q/qYMwo5PLZ_U.jpg?size=130x130&quality=96&sign=9d9581eb63bbbe9a32b01ac1f3bfd883&c_uniq_tag=uu1WIehKhGqGZJaqJGE51u5F7vwKzvbILoza_9-yPp0&type=album'},
#        {'height': 130,
#         'type': 'o',
#         'width': 130,
#         'url': 'https://sun1-17.userapi.com/impg/L4CuEfzTcLL5hpm56SPaU_P8mXb8u1dzdknY7Q/qYMwo5PLZ_U.jpg?size=130x130&quality=96&sign=9d9581eb63bbbe9a32b01ac1f3bfd883&c_uniq_tag=uu1WIehKhGqGZJaqJGE51u5F7vwKzvbILoza_9-yPp0&type=album'},
#        {'height': 200,
#         'type': 'p',
#         'width': 200,
#         'url': 'https://sun1-17.userapi.com/impg/L4CuEfzTcLL5hpm56SPaU_P8mXb8u1dzdknY7Q/qYMwo5PLZ_U.jpg?size=200x200&quality=96&sign=0c38a16438af20304d552edde89a259f&c_uniq_tag=eIic_hJ4lZOn2OqrzL1gs5P3cS2NKncLD3msPfw64J4&type=album'},
#        {'height': 320,
#         'type': 'q',
#         'width': 320,
#         'url': 'https://sun1-17.userapi.com/impg/L4CuEfzTcLL5hpm56SPaU_P8mXb8u1dzdknY7Q/qYMwo5PLZ_U.jpg?size=320x320&quality=96&sign=13a7816d798e5e0bef771ea90c532928&c_uniq_tag=gkiAdrb-5wF02JDXN-vZXWVWrDH6Ro2iO-3WbyXtuRw&type=album'},
#        {'height': 510,
#         'type': 'r',
#         'width': 510,
#         'url': 'https://sun1-17.userapi.com/impg/L4CuEfzTcLL5hpm56SPaU_P8mXb8u1dzdknY7Q/qYMwo5PLZ_U.jpg?size=510x510&quality=96&sign=9f1b451f1293636ac125a6f21dd5b55d&c_uniq_tag=5HqNQFq5P9qc-oEFAJXUn7aXktckzO6NqTgWRlsUEYs&type=album'},
#        {'height': 75,
#         'type': 's',
#         'width': 75,
#         'url': 'https://sun1-17.userapi.com/impg/L4CuEfzTcLL5hpm56SPaU_P8mXb8u1dzdknY7Q/qYMwo5PLZ_U.jpg?size=75x75&quality=96&sign=5623eb79e2a009e5f429cf093c7905b8&c_uniq_tag=Fdko-4q0G_DrvPkvFzNu8NPcTRuiWSFk5aymgtVAxWU&type=album'},
#        {'height': 2160,
#         'type': 'w',
#         'width': 2160,
#         'url': 'https://sun1-17.userapi.com/impg/L4CuEfzTcLL5hpm56SPaU_P8mXb8u1dzdknY7Q/qYMwo5PLZ_U.jpg?size=2160x2160&quality=96&sign=60c6f27d97fc639ce8e18835f0c9a8e6&c_uniq_tag=rg4li_WkpUXiAysCpxhV9ucqXBvlKEs36nIg3S3olkQ&type=album'},
#        {'height': 604,
#         'type': 'x',
#         'width': 604,
#         'url': 'https://sun1-17.userapi.com/impg/L4CuEfzTcLL5hpm56SPaU_P8mXb8u1dzdknY7Q/qYMwo5PLZ_U.jpg?size=604x604&quality=96&sign=91f9cf928e9acb956f76a08bec82764f&c_uniq_tag=RUzWuYkbPlHb8bBlmu5fF_Ow3uNfsxOFHHvA2ngGLfg&type=album'},
#        {'height': 807,
#         'type': 'y',
#         'width': 807,
#         'url': 'https://sun1-17.userapi.com/impg/L4CuEfzTcLL5hpm56SPaU_P8mXb8u1dzdknY7Q/qYMwo5PLZ_U.jpg?size=807x807&quality=96&sign=bd0816b8c16c4ba45e0f76e90aad2426&c_uniq_tag=iMPFKOs2GYXfaM-qa7XI-fKu9881eTRdyiM5n4YtRuw&type=album'},
#        {'height': 1280,
#         'type': 'z',
#         'width': 1280,
#         'url': 'https://sun1-17.userapi.com/impg/L4CuEfzTcLL5hpm56SPaU_P8mXb8u1dzdknY7Q/qYMwo5PLZ_U.jpg?size=1280x1280&quality=96&sign=12f631f295b29381642b2d161056d8b8&c_uniq_tag=Wn7z4l-kuHQr2iJg25ZGpcYK_brXTpwd82SgKbRhBAg&type=album'}],
#       'text': '',
#       'user_id': 100,
#       'web_view_token': 'cf915841e8f3029769',
#       'has_tags': False}}],
#    'date': 1716293364,
#    'from_id': -110302024,
#    'id': 1010,
#    'owner_id': -110302024,
#    'post_source': {'type': 'vk'},
#    'post_type': 'post',
#    'text': 'Дорогие студенты! \n \nПропал студент магистратуры и по совместительству преподаватель Школы дизайна Сабиров Гюльали Гафарович, 2001 года рождения. \n \nПоследний раз его видели около 6:00 в воскресенье (19.05) возле клуба «Симач в Недальнем», его телефон был найден возле станции метро Арбатская. \n \nПриметы Али: Рост 180 см, худощавое телосложение, темно-русые волосы, карие глаза. Он был одет в длинный серый плащ, синий пиджак, белую футболку, синие штаны и черные ботинки с красной подошвой. \n \nЕсли вы обладаете любой информацией, связанной с пропавшим или его нынешним местоположением, просим незамедлительно связаться с Инфоргом от LizaAlert: https://t.me/bananka_la, 89207060294. Мы также будем благодарны за распространение данной записи. \n\nВсю актуальную информацию можно узнать по ссылке: https://lizaalert.org/forum/viewtopic.php?t=77882&p=692835\n \nНа связи, \nВаш Студсовет!'}],
#  'donut': {'is_donut': False},
#  'comments': {'count': 0},
#  'marked_as_ads': 0,
#  'short_text_rate': 0.8,
#  'hash': 'ZCZbESEcSkFLKSLxAidl6WspOJwA',
#  'has_translation': False,
#  'type': 'post',
#  'attachments': [],
#  'date': 1716294173,
#  'from_id': -203966578,
#  'id': 541,
#  'is_favorite': False,
#  'likes': {'can_like': 0, 'count': 5, 'user_likes': 0},
#  'reaction_set_id': 'reactions',
#  'reactions': {'count': 5, 'items': [{'id': 0, 'count': 5}]},
#  'owner_id': -203966578,
#  'post_type': 'post',
#  'reposts': {'count': 0},
#  'text': '',
#  'views': {'count': 133}}

# %% [markdown]
# **Как получить из JSON файла `pandas.DataFrame`?**
# Есть два способа:
# * Либо использовать соответствующий метод `pandas`;
# * Либо использовать циклы.

# %% [markdown]
# **Вариант 1:** Мы можем использовать функцию `pandas.json_normalize` и превратить json-объект в `pandas.DataFrame`:

# %%
df_1 = pd.json_normalize(wall_data['response']['items']) # обратите внимание - обращаемся к items, а не всему ответу
df_1
# Out:
#       inner_type                                       copy_history
# 0  wall_wallpost  [{'inner_type': 'wall_wallpost', 'type': 'post...  \
# 1  wall_wallpost                                                NaN
# 2  wall_wallpost                                                NaN
# 3  wall_wallpost                                                NaN
# 4  wall_wallpost                                                NaN
#
#    marked_as_ads  short_text_rate                          hash
# 0              0              0.8  ZCZbESEcSkFLKSLxAidl6WspOJwA  \
# 1              0              0.8  Nd43y4j3Cze9PO4unc1xgs9yKrOs
# 2              0              0.8  t5V4hrh-4kZap-ylebbfNhR3nakr
# 3              0              0.8  uNrI_jG79WEqEs7dATEz_hCXLlSY
# 4              0              0.8  Sgr_2XWHEyhYAwxYInqtg_eAQa4o
#
#    has_translation  type                                        attachments
# 0            False  post                                                 []  \
# 1            False  post  [{'type': 'photo', 'photo': {'album_id': -7, '...
# 2            False  post  [{'type': 'photo', 'photo': {'album_id': -7, '...
# 3            False  post  [{'type': 'photo', 'photo': {'album_id': -7, '...
# 4            False  post  [{'type': 'link', 'link': {'url': 'https://m.v...
#
#          date    from_id  ...  comments.count  likes.can_like likes.count
# 0  1716294173 -203966578  ...               0               0           5  \
# 1  1716234582 -203966578  ...               5               0          10
# 2  1715277601 -203966578  ...               1               0          14
# 3  1713164404 -203966578  ...               1               0          15
# 4  1713025200 -203966578  ...               1               0          13
#
#    likes.user_likes reactions.count
# 0                 0               5  \
# 1                 0              10
# 2                 0              14
# 3                 0              15
# 4                 0              13
#
#                                   reactions.items  reposts.count  views.count
# 0                         [{'id': 0, 'count': 5}]              0          133  \
# 1  [{'id': 0, 'count': 9}, {'id': 4, 'count': 1}]             11          379
# 2                        [{'id': 0, 'count': 14}]             10          523
# 3                        [{'id': 0, 'count': 15}]              1         1470
# 4                        [{'id': 0, 'count': 13}]              3          499
#
#    carousel_offset        edited
# 0              NaN           NaN
# 1              0.0  1.716303e+09
# 2              0.0           NaN
# 3              NaN           NaN
# 4              NaN  1.713027e+09
#
# [5 rows x 27 columns]

# %% [markdown]
# Посмотрим, какие значения есть у нас в датафрейме:

# %%
df_1.columns
# Out:
# Index(['inner_type', 'copy_history', 'marked_as_ads', 'short_text_rate',
#        'hash', 'has_translation', 'type', 'attachments', 'date', 'from_id',
#        'id', 'is_favorite', 'reaction_set_id', 'owner_id', 'post_type', 'text',
#        'donut.is_donut', 'comments.count', 'likes.can_like', 'likes.count',
#        'likes.user_likes', 'reactions.count', 'reactions.items',
#        'reposts.count', 'views.count', 'carousel_offset', 'edited'],
#       dtype='object')

# %% [markdown]
# При желании, можем выбрать только часть колонок для дальнейшей работы:

# %%
df_1[['date', 'from_id', 'id', 'owner_id', 'post_type', 'text', 'likes.count', 'reposts.count', 'views.count']]
# Out:
#          date    from_id   id   owner_id post_type
# 0  1716294173 -203966578  541 -203966578      post  \
# 1  1716234582 -203966578  535 -203966578      post
# 2  1715277601 -203966578  533 -203966578      post
# 3  1713164404 -203966578  529 -203966578      post
# 4  1713025200 -203966578  526 -203966578      post
#
#                                                 text  likes.count
# 0                                                               5  \
# 1  ❗Check the English version in the comments!\n\...           10
# 2  Друзья!\n \nК нам поступила информация о раскл...           14
# 3  Дорогие вышкинцы!\n\nВ связи с чрезвычайной си...           15
# 4  Academic leave - simplified\n❗Check the Englis...           13
#
#    reposts.count  views.count
# 0              0          133
# 1             11          379
# 2             10          523
# 3              1         1470
# 4              3          499

# %% [markdown]
# **Вариант 2:** Можно воспользоваться циклами.

# %%
wall_data['response']['items'][1].keys() # все параметры одного поста
# Out:
# dict_keys(['inner_type', 'donut', 'comments', 'marked_as_ads', 'short_text_rate', 'hash', 'has_translation', 'type', 'carousel_offset', 'attachments', 'date', 'edited', 'from_id', 'id', 'is_favorite', 'likes', 'reaction_set_id', 'reactions', 'owner_id', 'post_type', 'reposts', 'text', 'views'])

# %% [markdown]
# Чтобы получить текст поста, нужно обратиться к первому элементу из `items` в нашем json: ```wall_data['response']['items'][0]```, а далее вызвать нужный атрибут: `['text']` (где `[0]` это индекс первого поста):

# %%
wall_data['response']['items'][1]['text'] # получим текст второго поста
# Out:
# '❗Check the English version in the comments!\n\nДорогие студенты и студентки 2 курса!\n \nВ этом году вы уже столкнулись с этапами Иннополиса, и сейчас мы хотим поподробнее рассказать, что вас ждет дальше и как подготовиться к следующим этапам.\n \nПрежде всего напоминаем, что всю основную информацию об Иннополисе можно найти здесь: https://vk.cc/cwZebJ\nА инструкции по работе с платформой тестирования — здесь: https://vk.cc/cwZe9b\n \nЕсли возникают проблемы в ходе тестирования, пишите по почте assesment.support@innopolis.university \nА о самом важном расскажем в карточках! \n\nС заботой,\nВаш Аппарат Уполномоченной!'

# %%
wall_data['response']['items'][1]['views'] # число просмотров
# Out:
# {'count': 327}

# %%
wall_data['response']['items'][1]['views']['count'] # чтобы получить конкретную цифру, нужно обратиться к параметру count
# Out:
# 327

# %%
wall_data['response']['items'][1]['likes'] # число лайков
# Out:
# {'can_like': 0, 'count': 9, 'user_likes': 0}

# %%
wall_data['response']['items'][1]['likes']['count'] # число лайков от пользователей
# Out:
# 9

# %% [markdown]
# А как собрать все эти данные вместе? Мы можем пользоваться генераторами списков и циклами:

# %%
# наглядное подтверждение:
for i in range(len(wall_data['response']['items'])):
    print(i) # эти индексы мы и будем в дальнейшем использовать
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
# Вариант один - просто с помощью цикла:

for i in range(len(wall_data['response']['items'])):
    print(wall_data['response']['items'][i]['views']) # печатаем то что содержится под ключом 'views'
# Out:
# {'count': 87}
# {'count': 327}
# {'count': 505}
# {'count': 1458}
# {'count': 491}

# %%
# чтобы получить точное число просмотров, обращаемся к ключу 'count'
for i in range(len(wall_data['response']['items'])):
    print(wall_data['response']['items'][i]['views']['count'])
# Out:
# 87
# 327
# 505
# 1458
# 491

# %% [markdown]
# Давайте соберем `pandas.DataFrame` с информацией о тех пяти постах, которые есть у нас в `wall_data`. Используя генераторы списков или циклы, сделаем следующее:
#
# **Создадим списки:**
# * `owner_ids` - список со значениями атрибута `owner_id` (кто запостил запись);
# * `dates` - список с датами публикаций каждого поста (*внутри будут странные целые числа, пока не обращайте внимание*);
# * `texts` - список с текстом каждого поста;
# * `likes` - список с числом лайков на каждом посте (целые числа);
# * `reposts` - список с числом репостов каждого поста.

# %%
owner_ids = [wall_data['response']['items'][i]['owner_id'] for i in range(len(wall_data['response']))]
dates = [wall_data['response']['items'][i]['date'] for i in range(len(wall_data['response']))]
texts = [wall_data['response']['items'][i]['text'] for i in range(len(wall_data['response']))]
likes = [wall_data['response']['items'][i]['likes']['count'] for i in range(len(wall_data['response']))]
reposts = [wall_data['response']['items'][i]['reposts']['count'] for i in range(len(wall_data['response']))]

# %% [markdown]
# **Создадим `posts` - `pandas.DataFrame` с информацией об этих постах:**
#
# Как создаются датафреймы в `pandas` можно посмотреть в [официальной документации](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.html):

# %%
posts = pd.DataFrame({'owner_id': owner_ids, # ключ - название колонки, значение - то, что там содержится
                     'date': dates,
                     'text': texts,
                     'likes': likes,
                     'reposts': reposts})
posts
# Out:
#     owner_id        date                                               text
# 0 -203966578  1716294173                                                     \
# 1 -203966578  1716234582  ❗Check the English version in the comments!\n\...
# 2 -203966578  1715277601  Друзья!\n \nК нам поступила информация о раскл...
# 3 -203966578  1713164404  Дорогие вышкинцы!\n\nВ связи с чрезвычайной си...
# 4 -203966578  1713025200  Academic leave - simplified\n❗Check the Englis...
#
#    likes  reposts
# 0      4        0
# 1      9        8
# 2     14       10
# 3     15        1
# 4     13        3

# %% [markdown]
# **После того, как мы с вами разобрались как работают запросы, объединим весь код в одну функцию – `get_last_posts()`:**

# %%
def get_last_posts(group_id, q=5, offset=0, method='wall.get'):
    parameters=f'owner_id=-{group_id}&count={q}&filter=owner&extended=1&offset={offset}&fields=name,screen_name,members_count'
    url = 'https://api.vk.com/method/' + method +'?'+ parameters + '&v=' + version + '&access_token=' + token
    response = requests.get(url) 
    wall_data = response.json()
    
    owner_ids = [wall_data['response']['items'][i]['owner_id'] for i in range(len(wall_data['response']['items']))]
    dates = [wall_data['response']['items'][i]['date'] for i in range(len(wall_data['response']['items']))]
    texts = [wall_data['response']['items'][i]['text'] for i in range(len(wall_data['response']['items']))]
    likes = [wall_data['response']['items'][i]['likes']['count'] for i in range(len(wall_data['response']['items']))]
    reposts = [wall_data['response']['items'][i]['reposts']['count'] for i in range(len(wall_data['response']['items']))]

    posts = pd.DataFrame({'owner_id': owner_ids,
                         'date': dates,
                         'text': texts,
                         'likes': likes,
                         'reposts': reposts})
    return posts

# %%
# Запустите эту ячейку. У вас должна получиться вот такая таблица:
get_last_posts(group_id=203966578, q=10, offset=0, method='wall.get')
# Out:
#     owner_id        date                                               text
# 0 -203966578  1716294173                                                     \
# 1 -203966578  1716234582  ❗Check the English version in the comments!\n\...
# 2 -203966578  1715277601  Друзья!\n \nК нам поступила информация о раскл...
# 3 -203966578  1713164404  Дорогие вышкинцы!\n\nВ связи с чрезвычайной си...
# 4 -203966578  1713025200  Academic leave - simplified\n❗Check the Englis...
# 5 -203966578  1712679000  Друзья! \n \nВ минувшую пятницу, 5 апреля, мно...
# 6 -203966578  1712078330
# 7 -203966578  1711980923  Друзья! \n \nВ последние несколько дней к нам ...
# 8 -203966578  1711893445  Друзья! \n \nУже завтра, 1 апреля, начнётся ве...
# 9 -203966578  1711727459  ‼️ Check the English version in Telegram — htt...
#
#    likes  reposts
# 0      5        0
# 1     10       11
# 2     14       10
# 3     15        1
# 4     13        3
# 5     16       12
# 6      3        0
# 7     12       16
# 8     33       49
# 9      2        1

# %% [markdown]
# Этот пример был нужен чтобы показать вам общую линию работы с API ВКонтакте: **как генерируется запрос**, **как понять какие данные вы можете получить**, **как их обработать** и **как собрать нормальную функцию из отдельных кусочков кода**.

# %% [markdown]
# ## API ВКонтакте:  `friends` <a name="par4"></a>
#
# Теперь давайте познакомимся еще с одним семейством методов API ВКонтакте – методами, связанными с получением информации о друзьях. Используем метод `friends.get` (документация доступна по [ссылке](https://dev.vk.com/ru/method/friends.get)).

# %%
method='friends.get'
parameters=f'order=name'

url = 'https://api.vk.com/method/' + method +'?'+ parameters + '&v=' + version + '&access_token=' + token
response = requests.get(url) 
my_friends = response.json()

# %%
# тут - число друзей и их id;
# my_friends

# %% [markdown]
# <p></p>
# <center><b><font size=4>Задача №2</font></b></center>
#
# **Запросите больше информации о ваших друзьях. Напишите функцию `get_my_friends()`, которая принимает на вход параметр `method` (используемый метод) и возвращает `pandas.DataFrame` с базовой информацией о ваших друзьях.**
#
#
# **Алгоритм решения:**
# 1. Изучите документацию метода `friends.get` по [ссылке](https://dev.vk.com/ru/method/friends.get);
# 2. Создайте переменную `parameters`, и добавьте туда нужные параметры:
#     * Вам нужна дополнительная информация о ваших друзьях (параметр `extended`);
#     * Дополнительные поля `fields`, которые вам нужны: дата рождения `bdate`, пол `sex`;
#     * Сортировка `order` - в алфавитном порядке.
# 3. Сгенерируйте внутри функции ссылку, которая содержит необходимые части для запроса;
# 4. Отправьте запрос и обработайте информацию;
# 5. Верните `pandas.DataFrame` со следующими колонками:
#     * `id` - id страницы;
#     * `first_name` – имя вашего друга;
#     * `last_name` – фамилия вашего друга;
#     * `sex` – пол;
#     * `bdate` – дата рождения вашего друга;
#     * `is_closed` – закрытый ли у него аккаунт.

# %%
# YOUR CODE HERE

# %%
# результат должен выглядеть так
my_friends = get_my_friends()
my_friends
# Out:
#             id first_name    last_name  sex      bdate  is_closed
# 0    463008298  Alexandra      Oorzhak    1       17.8      False
# 1    511785586      Alina          Ell    1   7.4.2004       True
# 2     53414043   Angelika  Zagashvilli    1  28.9.2000      False
# 3    501118101       Anna      Oorzhak    1        NaN       True
# 4    338357646      Anopa        Anopa    1      10.12      False
# ..         ...        ...          ...  ...        ...        ...
# 676  211058196       Monk         Monk    2        NaN       True
# 677  225843054  Анастасия    Анисимова    1      23.12       True
# 678  322747261        Ира        Голос    1      16.10      False
# 679  303010766     Полина       Музыка    1        1.2      False
# 680  182197491        Юля     Комарова    1  16.7.2000      False
#
# [681 rows x 6 columns]

# %% [markdown]
# На этом мы закончили краткое знакомство с работой API ВКонтакте. Хотя каждое API устроено по-своему, они работают на основе общих принципов, а API ВКонтакте может быть полезно вам, если вы хотите автоматизировать сбор данных из этой социальной сети или управлять своей страницей/пабликом по определенному скрипту. Сегодня мы с вами разобрались, что такое API и как оно работает, учились ориентироваться в документации, учились создавать запросы и обрабатывать json файлы.

# %% [markdown]
# ## Дополнительные материалы<a name="parlast"></a>
#
# - [Документация API ВКонтакте](https://dev.vk.com/ru/api/overview);
# - [Как получить токен для работы с API ВКонтакте](https://github.com/lika1kapustina/hse_polit_web-scraping/blob/main/api_vk_get_token_and_test.ipynb).
